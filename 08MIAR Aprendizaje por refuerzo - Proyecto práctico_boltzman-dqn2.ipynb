# %% [markdown]
# ### Proyecto práctico

# %% [markdown]
# Consideraciones a tener en cuenta:
#
# - El entorno sobre el que trabajaremos será _SpaceInvaders-v0_ y el algoritmo que usaremos será _DQN_.
#
# - Para nuestro ejercicio, una solución óptima será alcanzada cuando el agente consiga una **media de recompensa por encima de 20 puntos en modo test**. Por ello, esta media de la recompensa se calculará a partir del código de test en la última celda del notebook.

# %% [markdown]
# Este proyecto práctico consta de tres partes:
#
#    1) Implementar la red neuronal que se usará en la solución
#
#    2) Implementar las distintas piezas de la solución DQN
#
#    3) Justificar la respuesta en relación a los resultados obtenidos

# %% [markdown]
# IMPORTANTE:
#
# - Si no se consigue una puntuación óptima, responder sobre la mejor puntuación obtenida.
#
# - Para entrenamientos largos, recordad que podéis usar checkpoints de vuestros modelos para retomar los entrenamientos. En este caso, recordad cambiar los parámetros adecuadamente (sobre todo los relacionados con el proceso de exploración).
#
# - Tened en cuenta que las versiones de librerías recomendadas son Tensorflow==1.13.1, Keras==2.2.4 y keras-rl==0.4.2

# %% [markdown]
# #### Preparar entorno sobre TF2

# %%
# Conectamos con nuestro Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Establezco una ruta absoluta a un directorio existente de mi Google Drive (cambiar a drive propio)
BASE_FOLDER = "/content/drive/Othercomputers/My MacBook Pro/08_aprendizaje_por_refuerzo/proyecto/"
# Out:
# Mounted at /content/drive

# %%
# install keras-rl2 that works with tensorflow 2.x
# !pip install keras-rl2 > /dev/null 2>&1

# install gym and atari ROMs
# !pip install -U gym>=0.21.0
# !pip install -U gym[atari,accept-rom-license]
# Out:
# Requirement already satisfied: gym[accept-rom-license,atari] in /usr/local/lib/python3.7/dist-packages (0.21.0)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.7/dist-packages (from gym[accept-rom-license,atari]) (1.19.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym[accept-rom-license,atari]) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.8.1 in /usr/local/lib/python3.7/dist-packages (from gym[accept-rom-license,atari]) (4.8.2)
# Collecting ale-py~=0.7.1
#   Downloading ale_py-0.7.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 8.2 MB/s
# Collecting autorom[accept-rom-license]~=0.4.2
#   Downloading AutoROM-0.4.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from ale-py~=0.7.1->gym[accept-rom-license,atari]) (5.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (4.62.3)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (7.1.2)
# Collecting AutoROM.accept-rom-license
#   Downloading AutoROM.accept-rom-license-0.4.2.tar.gz (9.8 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.8.1->gym[accept-rom-license,atari]) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.8.1->gym[accept-rom-license,atari]) (3.6.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (2021.10.8)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (PEP 517) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.4.2-py3-none-any.whl size=441026 sha256=36f4d2fabcdb45a2f99825517d7aa4690661d5de5b50da0a2225f8243b4ea4ec
#   Stored in directory: /root/.cache/pip/wheels/87/67/2e/6147e7912fe37f5408b80d07527dab807c1d25f5c403a9538a
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: AutoROM.accept-rom-license, autorom, ale-py
# Successfully installed AutoROM.accept-rom-license-0.4.2 ale-py-0.7.3 autorom-0.4.2

# %%
# install the relevant libraries to make rendering possible
# !pip install pyvirtualdisplay > /dev/null 2>&1
# !apt-get update
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:6 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:8 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [73.9 kB]
# Get:9 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:12 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:14 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:15 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Hit:16 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:17 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,820 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [691 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,898 kB]
# Get:20 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,461 kB]
# Get:21 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,452 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,230 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-backports/main amd64 Packages [11.6 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-backports/universe amd64 Packages [12.6 kB]
# Get:25 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [933 kB]
# Get:26 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 Packages [45.9 kB]
# Fetched 12.9 MB in 4s (3,034 kB/s)
# Reading package lists... Done

# %%
# import the relevant libraries 
import gym
from gym import logger as gymlogger
from gym.wrappers import Monitor
gymlogger.set_level(40) #error only
import tensorflow as tf
import numpy as np
import math
import glob
import io
import base64
from IPython.display import HTML

from IPython import display as ipythondisplay
# Out:
# /usr/local/lib/python3.7/dist-packages/ale_py/roms/utils.py:90: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for external in metadata.entry_points().get(self.group, []):

# %%
"""
Utility functions to enable video recording of gym environment and displaying it
To enable video, just do "env = wrap_env(env)""
"""

def show_video():
  mp4list = glob.glob('video/*.mp4')
  if len(mp4list) > 0:
    mp4 = mp4list[0]
    video = io.open(mp4, 'r+b').read()
    encoded = base64.b64encode(video)
    ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
  else: 
    print("Could not find video")
    

def wrap_env(env):
  env = Monitor(env, './video', force=True)
  return env

# %% [markdown]
# #### Importar librerías

# %%
from __future__ import division

from PIL import Image
import numpy as np
import gym

from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Convolution2D, Permute, Dropout, BatchNormalization
#from keras.optimizers import Adam
from tensorflow.keras.optimizers import Adam
import keras.backend as K

from rl.agents.dqn import DQNAgent
from rl.policy import LinearAnnealedPolicy, BoltzmannQPolicy, EpsGreedyQPolicy
from rl.memory import SequentialMemory
from rl.core import Processor
from rl.callbacks import FileLogger, ModelIntervalCheckpoint

# %% [markdown]
# #### Configuración base

# %%
INPUT_SHAPE = (84, 84)
WINDOW_LENGTH = 4

env_name = 'SpaceInvaders-v0'
#env = wrap_env(gym.make(env_name))
env = gym.make(env_name)

np.random.seed(123)
env.seed(123)
nb_actions = env.action_space.n

# %%
class AtariProcessor(Processor):
    def process_observation(self, observation):
        assert observation.ndim == 3  # (height, width, channel)
        img = Image.fromarray(observation)
        img = img.resize(INPUT_SHAPE).convert('L') # a escala de grises
        processed_observation = np.array(img)
        assert processed_observation.shape == INPUT_SHAPE
        return processed_observation.astype('uint8') # casting a 8 bits

    def process_state_batch(self, batch):
        processed_batch = batch.astype('float32') / 255. # normalizar entre 0 y 1
        return processed_batch

    def process_reward(self, reward):
        return np.clip(reward, -1., 1.) # se acota para que no sea tan sensible a valores extremos

# %%
# Acciones disponibles en el entorno
nb_actions = env.action_space.n
nb_actions
# Out:
# 6

# %%
# Nombres de las acciones
env.unwrapped.get_action_meanings()
# Out:
# ['NOOP', 'FIRE', 'RIGHT', 'LEFT', 'RIGHTFIRE', 'LEFTFIRE']

# %%
# Dimensions de las observaciones del entorno
env.observation_space.shape
# Out:
# (210, 160, 3)

# %% [markdown]
# 1) Implementación de la red neuronal

# %%
# Next, we build our model. We use the same model that was described by Mnih et al. (2015).
input_shape = (WINDOW_LENGTH,) + INPUT_SHAPE
model = Sequential()

# segun el backend, se usa un ordenamiento de dimensiones diferente (para tensorflow o theano)
#if K.image_dim_ordering() == 'tf':
if K.image_data_format() == 'channels_last':
    # (width, height, channels)
    model.add(Permute((2, 3, 1), input_shape=input_shape))
#elif K.image_dim_ordering() == 'th':
elif image_data_format() == 'channels_first':
    # (channels, width, height)
    model.add(Permute((1, 2, 3), input_shape=input_shape))
else:
    raise RuntimeError('Unknown image_dim_ordering.')
# conv_1
model.add(Convolution2D(32, (8, 8), strides=(4, 4)))
model.add(Activation('relu'))
# conv_2
model.add(Convolution2D(64, (4, 4), strides=(2, 2)))
model.add(Activation('relu'))
# conv_3
model.add(Convolution2D(64, (3, 3), strides=(1, 1)))
model.add(Activation('relu'))
# FC
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dense(nb_actions))
model.add(Activation('linear')) # lineal porque son las recompensas esperadas a futuro para cada accion (nb_actions)
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  permute (Permute)           (None, 84, 84, 4)         0
#
#  conv2d (Conv2D)             (None, 20, 20, 32)        8224
#
#  activation (Activation)     (None, 20, 20, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 9, 9, 64)          32832
#
#  activation_1 (Activation)   (None, 9, 9, 64)          0
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 64)          36928
#
#  activation_2 (Activation)   (None, 7, 7, 64)          0
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 512)               1606144
#
#  activation_3 (Activation)   (None, 512)               0
#
#  dense_1 (Dense)             (None, 6)                 3078
#
#  activation_4 (Activation)   (None, 6)                 0
#
# =================================================================
# Total params: 1,687,206
# Trainable params: 1,687,206
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# 2) Implementación de la solución DQN

# %%
memory = SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH)
processor = AtariProcessor()

# %%
# BoltzmannQPolicy selects an action stochastically with a probability generated by soft-maxing Q values
policy = BoltzmannQPolicy()

# %%
# recordar que el modelo se 'duplica' uno para target y otro para predicción, ambos idénticos
# gamma es el discount factor de las rewards
# target se actualiza cada 10000 steps
# cada 20 steps, se actualizan los pesos del modelo
# bajamos el learning rate
dqn = DQNAgent(model=model, nb_actions=nb_actions, policy=policy,
               memory=memory, processor=processor,
               nb_steps_warmup=50000, gamma=.99,
               target_model_update=20000,
               train_interval=20)
dqn.compile(Adam(learning_rate=.00025), metrics=['mae'])

# %%
# Training part
# log en pantalla cada 10,000 steps
# cada 250000 steps almaceno versiones del modelo (callbacks)
# el log escrito, cada 100 steps
weights_filename = BASE_FOLDER+'dqn2_boltz_{}_weights.h5f'.format(env_name)
checkpoint_weights_filename = BASE_FOLDER+'dqn2_boltz_' + env_name + '_weights_{step}.h5f'
log_filename = BASE_FOLDER+'dqn2_boltz_{}_log.json'.format(env_name)
callbacks = [ModelIntervalCheckpoint(checkpoint_weights_filename, interval=250000)]
callbacks += [FileLogger(log_filename, interval=100)]

dqn.fit(env, callbacks=callbacks, nb_steps=2000000, log_interval=10000, visualize=False)

dqn.save_weights(weights_filename, overwrite=True)
# Out:
# Training for 2000000 steps ...
# Interval 1 (0 steps performed)
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 10000/10000 [==============================] - 51s 4ms/step - reward: 0.0134
# 15 episodes - episode_reward: 8.467 [2.000, 14.000] - lives: 2.100
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 42s 4ms/step - reward: 0.0113
# 14 episodes - episode_reward: 8.286 [4.000, 13.000] - lives: 2.068
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 43s 4ms/step - reward: 0.0144
# 16 episodes - episode_reward: 8.750 [4.000, 21.000] - lives: 2.151
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 43s 4ms/step - reward: 0.0133
# 14 episodes - episode_reward: 9.571 [2.000, 17.000] - lives: 2.089
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 43s 4ms/step - reward: 0.0122
# 18 episodes - episode_reward: 7.167 [2.000, 15.000] - lives: 2.039
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 82s 8ms/step - reward: 0.0143
# 15 episodes - episode_reward: 9.133 [3.000, 19.000] - loss: 0.006 - mae: 0.029 - mean_q: 0.043 - lives: 2.185
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 79s 8ms/step - reward: 0.0123
# 16 episodes - episode_reward: 7.562 [2.000, 15.000] - loss: 0.006 - mae: 0.042 - mean_q: 0.058 - lives: 2.189
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 77s 8ms/step - reward: 0.0127
# 17 episodes - episode_reward: 7.941 [3.000, 15.000] - loss: 0.006 - mae: 0.055 - mean_q: 0.072 - lives: 2.146
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 79s 8ms/step - reward: 0.0120
# 13 episodes - episode_reward: 8.615 [3.000, 16.000] - loss: 0.006 - mae: 0.082 - mean_q: 0.106 - lives: 2.127
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 80s 8ms/step - reward: 0.0142
# 14 episodes - episode_reward: 10.500 [2.000, 18.000] - loss: 0.007 - mae: 0.097 - mean_q: 0.121 - lives: 1.998
#
# Interval 11 (100000 steps performed)
# 10000/10000 [==============================] - 77s 8ms/step - reward: 0.0141
# 15 episodes - episode_reward: 9.400 [4.000, 16.000] - loss: 0.007 - mae: 0.112 - mean_q: 0.139 - lives: 2.136
#
# Interval 12 (110000 steps performed)
# 10000/10000 [==============================] - 75s 8ms/step - reward: 0.0126
# 13 episodes - episode_reward: 9.769 [6.000, 17.000] - loss: 0.007 - mae: 0.133 - mean_q: 0.166 - lives: 1.985
#
# Interval 13 (120000 steps performed)
# 10000/10000 [==============================] - 76s 8ms/step - reward: 0.0125
# 15 episodes - episode_reward: 8.200 [2.000, 15.000] - loss: 0.007 - mae: 0.171 - mean_q: 0.214 - lives: 2.034
#
# Interval 14 (130000 steps performed)
# 10000/10000 [==============================] - 76s 8ms/step - reward: 0.0137
# 14 episodes - episode_reward: 9.857 [3.000, 18.000] - loss: 0.006 - mae: 0.198 - mean_q: 0.244 - lives: 2.067
#
# Interval 15 (140000 steps performed)
# 10000/10000 [==============================] - 83s 8ms/step - reward: 0.0129
# 14 episodes - episode_reward: 9.429 [6.000, 18.000] - loss: 0.007 - mae: 0.220 - mean_q: 0.272 - lives: 2.046
#
# Interval 16 (150000 steps performed)
# 10000/10000 [==============================] - 80s 8ms/step - reward: 0.0123
# 13 episodes - episode_reward: 8.000 [1.000, 12.000] - loss: 0.006 - mae: 0.245 - mean_q: 0.301 - lives: 2.031
#
# Interval 17 (160000 steps performed)
# 10000/10000 [==============================] - 81s 8ms/step - reward: 0.0140
# 15 episodes - episode_reward: 9.733 [3.000, 19.000] - loss: 0.006 - mae: 0.275 - mean_q: 0.338 - lives: 2.123
#
# Interval 18 (170000 steps performed)
# 10000/10000 [==============================] - 78s 8ms/step - reward: 0.0133
# 15 episodes - episode_reward: 9.667 [3.000, 18.000] - loss: 0.007 - mae: 0.292 - mean_q: 0.358 - lives: 2.173
#
# Interval 19 (180000 steps performed)
# 10000/10000 [==============================] - 83s 8ms/step - reward: 0.0123
# 16 episodes - episode_reward: 7.562 [2.000, 14.000] - loss: 0.006 - mae: 0.311 - mean_q: 0.381 - lives: 2.050
#
# Interval 20 (190000 steps performed)
# 10000/10000 [==============================] - 80s 8ms/step - reward: 0.0125
# 14 episodes - episode_reward: 8.357 [2.000, 14.000] - loss: 0.007 - mae: 0.339 - mean_q: 0.413 - lives: 2.126
#
# Interval 21 (200000 steps performed)
# 10000/10000 [==============================] - 80s 8ms/step - reward: 0.0136
# 14 episodes - episode_reward: 9.429 [3.000, 16.000] - loss: 0.007 - mae: 0.347 - mean_q: 0.423 - lives: 2.061
#
# Interval 22 (210000 steps performed)
# 10000/10000 [==============================] - 80s 8ms/step - reward: 0.0132
# 15 episodes - episode_reward: 8.867 [3.000, 20.000] - loss: 0.007 - mae: 0.390 - mean_q: 0.475 - lives: 2.090
#
# Interval 23 (220000 steps performed)
# 10000/10000 [==============================] - 83s 8ms/step - reward: 0.0138
# 15 episodes - episode_reward: 9.600 [4.000, 17.000] - loss: 0.007 - mae: 0.399 - mean_q: 0.486 - lives: 2.220
#
# Interval 24 (230000 steps performed)
# 10000/10000 [==============================] - 81s 8ms/step - reward: 0.0129
# 13 episodes - episode_reward: 9.846 [5.000, 21.000] - loss: 0.007 - mae: 0.422 - mean_q: 0.515 - lives: 2.300
#
# Interval 25 (240000 steps performed)
# 10000/10000 [==============================] - 84s 8ms/step - reward: 0.0142
# 12 episodes - episode_reward: 12.500 [4.000, 36.000] - loss: 0.007 - mae: 0.440 - mean_q: 0.535 - lives: 2.173
#
# Interval 26 (250000 steps performed)
# 10000/10000 [==============================] - 84s 8ms/step - reward: 0.0139
# 13 episodes - episode_reward: 10.692 [5.000, 19.000] - loss: 0.008 - mae: 0.489 - mean_q: 0.594 - lives: 2.211
#
# Interval 27 (260000 steps performed)
# 10000/10000 [==============================] - 86s 9ms/step - reward: 0.0133
# 14 episodes - episode_reward: 9.071 [3.000, 23.000] - loss: 0.008 - mae: 0.492 - mean_q: 0.596 - lives: 2.073
#
# Interval 28 (270000 steps performed)
# 10000/10000 [==============================] - 83s 8ms/step - reward: 0.0147
# 14 episodes - episode_reward: 11.000 [4.000, 19.000] - loss: 0.008 - mae: 0.509 - mean_q: 0.618 - lives: 2.023
#
# Interval 29 (280000 steps performed)
# 10000/10000 [==============================] - 83s 8ms/step - reward: 0.0146
# 12 episodes - episode_reward: 11.583 [3.000, 28.000] - loss: 0.007 - mae: 0.528 - mean_q: 0.640 - lives: 2.038
#
# Interval 30 (290000 steps performed)
# 10000/10000 [==============================] - 84s 8ms/step - reward: 0.0120
# 17 episodes - episode_reward: 7.471 [3.000, 15.000] - loss: 0.008 - mae: 0.543 - mean_q: 0.657 - lives: 2.061
#
# Interval 31 (300000 steps performed)
# 10000/10000 [==============================] - 87s 9ms/step - reward: 0.0143
# 16 episodes - episode_reward: 7.875 [3.000, 13.000] - loss: 0.008 - mae: 0.582 - mean_q: 0.704 - lives: 2.114
#
# Interval 32 (310000 steps performed)
# 10000/10000 [==============================] - 85s 8ms/step - reward: 0.0135
# 14 episodes - episode_reward: 9.929 [4.000, 23.000] - loss: 0.008 - mae: 0.617 - mean_q: 0.748 - lives: 2.070
#
# Interval 33 (320000 steps performed)
# 10000/10000 [==============================] - 86s 9ms/step - reward: 0.0142
# 15 episodes - episode_reward: 10.067 [6.000, 18.000] - loss: 0.008 - mae: 0.641 - mean_q: 0.775 - lives: 2.114
#
# Interval 34 (330000 steps performed)
# 10000/10000 [==============================] - 84s 8ms/step - reward: 0.0135
# 15 episodes - episode_reward: 8.867 [4.000, 15.000] - loss: 0.009 - mae: 0.657 - mean_q: 0.795 - lives: 2.096
#
# Interval 35 (340000 steps performed)
# 10000/10000 [==============================] - 89s 9ms/step - reward: 0.0143
# 14 episodes - episode_reward: 10.286 [4.000, 21.000] - loss: 0.009 - mae: 0.658 - mean_q: 0.795 - lives: 2.072
#
# Interval 36 (350000 steps performed)
# 10000/10000 [==============================] - 88s 9ms/step - reward: 0.0133
# 15 episodes - episode_reward: 8.933 [4.000, 19.000] - loss: 0.008 - mae: 0.687 - mean_q: 0.833 - lives: 2.077
#
# Interval 37 (360000 steps performed)
# 10000/10000 [==============================] - 87s 9ms/step - reward: 0.0132
# 15 episodes - episode_reward: 9.000 [3.000, 24.000] - loss: 0.007 - mae: 0.682 - mean_q: 0.824 - lives: 2.104
#
# Interval 38 (370000 steps performed)
# 10000/10000 [==============================] - 88s 9ms/step - reward: 0.0122
# 12 episodes - episode_reward: 9.917 [5.000, 19.000] - loss: 0.008 - mae: 0.703 - mean_q: 0.849 - lives: 1.993
#
# Interval 39 (380000 steps performed)
# 10000/10000 [==============================] - 90s 9ms/step - reward: 0.0129
# 15 episodes - episode_reward: 8.533 [3.000, 19.000] - loss: 0.008 - mae: 0.727 - mean_q: 0.880 - lives: 2.147
#
# Interval 40 (390000 steps performed)
# 10000/10000 [==============================] - 89s 9ms/step - reward: 0.0132
# 13 episodes - episode_reward: 10.154 [4.000, 17.000] - loss: 0.008 - mae: 0.763 - mean_q: 0.922 - lives: 2.135
#
# Interval 41 (400000 steps performed)
# 10000/10000 [==============================] - 89s 9ms/step - reward: 0.0130
# 15 episodes - episode_reward: 8.267 [4.000, 16.000] - loss: 0.008 - mae: 0.788 - mean_q: 0.953 - lives: 2.098
#
# Interval 42 (410000 steps performed)
# 10000/10000 [==============================] - 89s 9ms/step - reward: 0.0127
# 15 episodes - episode_reward: 9.133 [3.000, 18.000] - loss: 0.009 - mae: 0.803 - mean_q: 0.971 - lives: 1.979
#
# Interval 43 (420000 steps performed)
# 10000/10000 [==============================] - 90s 9ms/step - reward: 0.0139
# 15 episodes - episode_reward: 8.600 [4.000, 22.000] - loss: 0.008 - mae: 0.803 - mean_q: 0.972 - lives: 2.258
#
# Interval 44 (430000 steps performed)
# 10000/10000 [==============================] - 90s 9ms/step - reward: 0.0119
# 13 episodes - episode_reward: 9.462 [1.000, 23.000] - loss: 0.009 - mae: 0.835 - mean_q: 1.010 - lives: 2.005
#
# Interval 45 (440000 steps performed)
# 10000/10000 [==============================] - 89s 9ms/step - reward: 0.0128
# 16 episodes - episode_reward: 8.375 [5.000, 17.000] - loss: 0.008 - mae: 0.854 - mean_q: 1.035 - lives: 2.101
#
# Interval 46 (450000 steps performed)
# 10000/10000 [==============================] - 92s 9ms/step - reward: 0.0142
# 15 episodes - episode_reward: 9.467 [5.000, 21.000] - loss: 0.009 - mae: 0.867 - mean_q: 1.050 - lives: 2.123
#
# Interval 47 (460000 steps performed)
# 10000/10000 [==============================] - 90s 9ms/step - reward: 0.0126
# 14 episodes - episode_reward: 9.071 [4.000, 17.000] - loss: 0.009 - mae: 0.902 - mean_q: 1.092 - lives: 2.142
#
# Interval 48 (470000 steps performed)
# 10000/10000 [==============================] - 90s 9ms/step - reward: 0.0134
# 14 episodes - episode_reward: 9.500 [3.000, 18.000] - loss: 0.008 - mae: 0.913 - mean_q: 1.104 - lives: 2.095
#
# Interval 49 (480000 steps performed)
# 10000/10000 [==============================] - 91s 9ms/step - reward: 0.0145
# 12 episodes - episode_reward: 10.917 [5.000, 17.000] - loss: 0.009 - mae: 0.945 - mean_q: 1.141 - lives: 2.014
#
# Interval 50 (490000 steps performed)
# 10000/10000 [==============================] - 94s 9ms/step - reward: 0.0157
# 17 episodes - episode_reward: 9.765 [2.000, 20.000] - loss: 0.009 - mae: 0.950 - mean_q: 1.149 - lives: 2.013
#
# Interval 51 (500000 steps performed)
# 10000/10000 [==============================] - 92s 9ms/step - reward: 0.0151
# 15 episodes - episode_reward: 10.267 [5.000, 17.000] - loss: 0.009 - mae: 0.984 - mean_q: 1.191 - lives: 2.093
#
# Interval 52 (510000 steps performed)
# 10000/10000 [==============================] - 92s 9ms/step - reward: 0.0142
# 15 episodes - episode_reward: 9.400 [2.000, 31.000] - loss: 0.009 - mae: 1.002 - mean_q: 1.214 - lives: 2.137
#
# Interval 53 (520000 steps performed)
# 10000/10000 [==============================] - 92s 9ms/step - reward: 0.0150
# 12 episodes - episode_reward: 11.917 [2.000, 24.000] - loss: 0.009 - mae: 1.023 - mean_q: 1.238 - lives: 2.147
#
# Interval 54 (530000 steps performed)
# 10000/10000 [==============================] - 93s 9ms/step - reward: 0.0136
# 14 episodes - episode_reward: 9.786 [3.000, 16.000] - loss: 0.009 - mae: 1.047 - mean_q: 1.267 - lives: 2.095
#
# Interval 55 (540000 steps performed)
# 10000/10000 [==============================] - 90s 9ms/step - reward: 0.0131
# 15 episodes - episode_reward: 8.533 [4.000, 19.000] - loss: 0.010 - mae: 1.065 - mean_q: 1.288 - lives: 2.147
#
# Interval 56 (550000 steps performed)
# 10000/10000 [==============================] - 93s 9ms/step - reward: 0.0143
# 15 episodes - episode_reward: 9.733 [6.000, 20.000] - loss: 0.010 - mae: 1.093 - mean_q: 1.322 - lives: 2.067
#
# Interval 57 (560000 steps performed)
# 10000/10000 [==============================] - 95s 9ms/step - reward: 0.0140
# 14 episodes - episode_reward: 10.500 [5.000, 21.000] - loss: 0.010 - mae: 1.138 - mean_q: 1.378 - lives: 2.216
#
# Interval 58 (570000 steps performed)
# 10000/10000 [==============================] - 91s 9ms/step - reward: 0.0138
# 12 episodes - episode_reward: 11.083 [3.000, 21.000] - loss: 0.010 - mae: 1.150 - mean_q: 1.392 - lives: 2.097
#
# Interval 59 (580000 steps performed)
# 10000/10000 [==============================] - 94s 9ms/step - reward: 0.0128
# 15 episodes - episode_reward: 9.067 [6.000, 14.000] - loss: 0.010 - mae: 1.164 - mean_q: 1.409 - lives: 2.094
#
# Interval 60 (590000 steps performed)
# 10000/10000 [==============================] - 95s 9ms/step - reward: 0.0136
# 12 episodes - episode_reward: 11.333 [6.000, 16.000] - loss: 0.009 - mae: 1.178 - mean_q: 1.426 - lives: 2.047
#
# Interval 61 (600000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0128
# 13 episodes - episode_reward: 9.769 [3.000, 16.000] - loss: 0.010 - mae: 1.201 - mean_q: 1.454 - lives: 2.125
#
# Interval 62 (610000 steps performed)
# 10000/10000 [==============================] - 94s 9ms/step - reward: 0.0139
# 15 episodes - episode_reward: 9.333 [3.000, 22.000] - loss: 0.010 - mae: 1.212 - mean_q: 1.467 - lives: 2.132
#
# Interval 63 (620000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0140
# 13 episodes - episode_reward: 10.538 [5.000, 16.000] - loss: 0.010 - mae: 1.241 - mean_q: 1.504 - lives: 2.175
#
# Interval 64 (630000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0150
# 14 episodes - episode_reward: 10.500 [5.000, 19.000] - loss: 0.010 - mae: 1.264 - mean_q: 1.532 - lives: 1.998
#
# Interval 65 (640000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0148
# 14 episodes - episode_reward: 10.429 [5.000, 16.000] - loss: 0.010 - mae: 1.282 - mean_q: 1.554 - lives: 2.046
#
# Interval 66 (650000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0135
# 15 episodes - episode_reward: 9.000 [2.000, 18.000] - loss: 0.010 - mae: 1.299 - mean_q: 1.574 - lives: 2.080
#
# Interval 67 (660000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0148
# 15 episodes - episode_reward: 10.400 [4.000, 20.000] - loss: 0.009 - mae: 1.316 - mean_q: 1.594 - lives: 2.132
#
# Interval 68 (670000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0135
# 14 episodes - episode_reward: 9.000 [4.000, 15.000] - loss: 0.011 - mae: 1.347 - mean_q: 1.631 - lives: 2.020
#
# Interval 69 (680000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0133
# 15 episodes - episode_reward: 8.667 [4.000, 15.000] - loss: 0.010 - mae: 1.363 - mean_q: 1.649 - lives: 2.075
#
# Interval 70 (690000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0144
# 15 episodes - episode_reward: 10.067 [5.000, 21.000] - loss: 0.010 - mae: 1.372 - mean_q: 1.661 - lives: 2.023
#
# Interval 71 (700000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0132
# 12 episodes - episode_reward: 11.000 [3.000, 18.000] - loss: 0.009 - mae: 1.381 - mean_q: 1.673 - lives: 2.201
#
# Interval 72 (710000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0131
# 14 episodes - episode_reward: 9.071 [3.000, 22.000] - loss: 0.010 - mae: 1.411 - mean_q: 1.710 - lives: 2.098
#
# Interval 73 (720000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0147
# 14 episodes - episode_reward: 11.143 [4.000, 20.000] - loss: 0.010 - mae: 1.455 - mean_q: 1.761 - lives: 1.979
#
# Interval 74 (730000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0139
# 16 episodes - episode_reward: 8.125 [4.000, 16.000] - loss: 0.011 - mae: 1.477 - mean_q: 1.788 - lives: 2.144
#
# Interval 75 (740000 steps performed)
# 10000/10000 [==============================] - 102s 10ms/step - reward: 0.0153
# 13 episodes - episode_reward: 11.231 [6.000, 17.000] - loss: 0.010 - mae: 1.492 - mean_q: 1.805 - lives: 2.122
#
# Interval 76 (750000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0135
# 14 episodes - episode_reward: 10.786 [5.000, 22.000] - loss: 0.011 - mae: 1.494 - mean_q: 1.806 - lives: 2.080
#
# Interval 77 (760000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0141
# 15 episodes - episode_reward: 9.000 [4.000, 24.000] - loss: 0.010 - mae: 1.536 - mean_q: 1.858 - lives: 2.298
#
# Interval 78 (770000 steps performed)
# 10000/10000 [==============================] - 103s 10ms/step - reward: 0.0136
# 15 episodes - episode_reward: 9.067 [4.000, 19.000] - loss: 0.011 - mae: 1.533 - mean_q: 1.853 - lives: 2.121
#
# Interval 79 (780000 steps performed)
# 10000/10000 [==============================] - 101s 10ms/step - reward: 0.0146
# 15 episodes - episode_reward: 9.533 [5.000, 20.000] - loss: 0.010 - mae: 1.555 - mean_q: 1.879 - lives: 2.179
#
# Interval 80 (790000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0152
# 13 episodes - episode_reward: 11.538 [4.000, 28.000] - loss: 0.010 - mae: 1.577 - mean_q: 1.905 - lives: 2.111
#
# Interval 81 (800000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0140
# 15 episodes - episode_reward: 10.067 [4.000, 17.000] - loss: 0.010 - mae: 1.592 - mean_q: 1.923 - lives: 2.150
#
# Interval 82 (810000 steps performed)
# 10000/10000 [==============================] - 102s 10ms/step - reward: 0.0164
# 15 episodes - episode_reward: 10.600 [3.000, 21.000] - loss: 0.010 - mae: 1.582 - mean_q: 1.912 - lives: 2.117
#
# Interval 83 (820000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0143
# 14 episodes - episode_reward: 9.929 [4.000, 24.000] - loss: 0.010 - mae: 1.616 - mean_q: 1.950 - lives: 2.035
#
# Interval 84 (830000 steps performed)
# 10000/10000 [==============================] - 101s 10ms/step - reward: 0.0158
# 15 episodes - episode_reward: 10.867 [4.000, 24.000] - loss: 0.009 - mae: 1.635 - mean_q: 1.974 - lives: 2.007
#
# Interval 85 (840000 steps performed)
# 10000/10000 [==============================] - 102s 10ms/step - reward: 0.0147
# 14 episodes - episode_reward: 10.429 [2.000, 20.000] - loss: 0.011 - mae: 1.636 - mean_q: 1.975 - lives: 2.170
#
# Interval 86 (850000 steps performed)
# 10000/10000 [==============================] - 102s 10ms/step - reward: 0.0141
# 14 episodes - episode_reward: 10.071 [2.000, 24.000] - loss: 0.011 - mae: 1.650 - mean_q: 1.994 - lives: 2.207
#
# Interval 87 (860000 steps performed)
# 10000/10000 [==============================] - 102s 10ms/step - reward: 0.0150
# 15 episodes - episode_reward: 10.200 [4.000, 22.000] - loss: 0.011 - mae: 1.646 - mean_q: 1.986 - lives: 2.062
#
# Interval 88 (870000 steps performed)
# 10000/10000 [==============================] - 105s 10ms/step - reward: 0.0139
# 15 episodes - episode_reward: 8.933 [6.000, 13.000] - loss: 0.011 - mae: 1.641 - mean_q: 1.981 - lives: 2.100
#
# Interval 89 (880000 steps performed)
# 10000/10000 [==============================] - 103s 10ms/step - reward: 0.0147
# 13 episodes - episode_reward: 11.538 [6.000, 18.000] - loss: 0.010 - mae: 1.661 - mean_q: 2.005 - lives: 2.152
#
# Interval 90 (890000 steps performed)
# 10000/10000 [==============================] - 104s 10ms/step - reward: 0.0123
# 15 episodes - episode_reward: 8.467 [3.000, 16.000] - loss: 0.010 - mae: 1.656 - mean_q: 1.997 - lives: 2.000
#
# Interval 91 (900000 steps performed)
# 10000/10000 [==============================] - 105s 10ms/step - reward: 0.0140
# 15 episodes - episode_reward: 8.400 [4.000, 18.000] - loss: 0.010 - mae: 1.680 - mean_q: 2.029 - lives: 2.098
#
# Interval 92 (910000 steps performed)
# 10000/10000 [==============================] - 104s 10ms/step - reward: 0.0137
# 13 episodes - episode_reward: 11.000 [3.000, 24.000] - loss: 0.010 - mae: 1.683 - mean_q: 2.031 - lives: 2.013
#
# Interval 93 (920000 steps performed)
# 10000/10000 [==============================] - 103s 10ms/step - reward: 0.0140
# 13 episodes - episode_reward: 10.692 [4.000, 20.000] - loss: 0.011 - mae: 1.721 - mean_q: 2.074 - lives: 1.938
#
# Interval 94 (930000 steps performed)
# 10000/10000 [==============================] - 105s 11ms/step - reward: 0.0144
# 14 episodes - episode_reward: 10.857 [6.000, 16.000] - loss: 0.010 - mae: 1.691 - mean_q: 2.040 - lives: 2.155
#
# Interval 95 (940000 steps performed)
# 10000/10000 [==============================] - 106s 11ms/step - reward: 0.0137
# 17 episodes - episode_reward: 7.647 [4.000, 12.000] - loss: 0.010 - mae: 1.703 - mean_q: 2.055 - lives: 2.199
#
# Interval 96 (950000 steps performed)
# 10000/10000 [==============================] - 107s 11ms/step - reward: 0.0122
# 14 episodes - episode_reward: 9.286 [2.000, 20.000] - loss: 0.011 - mae: 1.722 - mean_q: 2.077 - lives: 2.090
#
# Interval 97 (960000 steps performed)
# 10000/10000 [==============================] - 108s 11ms/step - reward: 0.0129
# 14 episodes - episode_reward: 9.214 [3.000, 17.000] - loss: 0.011 - mae: 1.726 - mean_q: 2.083 - lives: 2.029
#
# Interval 98 (970000 steps performed)
# 10000/10000 [==============================] - 108s 11ms/step - reward: 0.0151
# 14 episodes - episode_reward: 9.714 [1.000, 22.000] - loss: 0.011 - mae: 1.743 - mean_q: 2.103 - lives: 1.976
#
# Interval 99 (980000 steps performed)
# 10000/10000 [==============================] - 105s 11ms/step - reward: 0.0129
# 15 episodes - episode_reward: 9.000 [5.000, 20.000] - loss: 0.011 - mae: 1.749 - mean_q: 2.109 - lives: 1.964
#
# Interval 100 (990000 steps performed)
# 10000/10000 [==============================] - 107s 11ms/step - reward: 0.0129
# 14 episodes - episode_reward: 9.857 [4.000, 16.000] - loss: 0.011 - mae: 1.753 - mean_q: 2.113 - lives: 2.205
#
# Interval 101 (1000000 steps performed)
# 10000/10000 [==============================] - 107s 11ms/step - reward: 0.0142
# 15 episodes - episode_reward: 9.267 [4.000, 20.000] - loss: 0.011 - mae: 1.756 - mean_q: 2.118 - lives: 2.106
#
# Interval 102 (1010000 steps performed)
# 10000/10000 [==============================] - 107s 11ms/step - reward: 0.0131
# 14 episodes - episode_reward: 9.500 [5.000, 20.000] - loss: 0.011 - mae: 1.798 - mean_q: 2.168 - lives: 2.048
#
# Interval 103 (1020000 steps performed)
# 10000/10000 [==============================] - 107s 11ms/step - reward: 0.0138
# 13 episodes - episode_reward: 10.385 [3.000, 17.000] - loss: 0.010 - mae: 1.812 - mean_q: 2.185 - lives: 2.091
#
# Interval 104 (1030000 steps performed)
# 10000/10000 [==============================] - 107s 11ms/step - reward: 0.0130
# 14 episodes - episode_reward: 9.286 [3.000, 17.000] - loss: 0.010 - mae: 1.823 - mean_q: 2.197 - lives: 2.017
#
# Interval 105 (1040000 steps performed)
# 10000/10000 [==============================] - 106s 11ms/step - reward: 0.0138
# 15 episodes - episode_reward: 9.067 [5.000, 21.000] - loss: 0.011 - mae: 1.802 - mean_q: 2.173 - lives: 2.224
#
# Interval 106 (1050000 steps performed)
# 10000/10000 [==============================] - 109s 11ms/step - reward: 0.0122
# 13 episodes - episode_reward: 9.385 [3.000, 23.000] - loss: 0.010 - mae: 1.832 - mean_q: 2.208 - lives: 2.184
#
# Interval 107 (1060000 steps performed)
# 10000/10000 [==============================] - 108s 11ms/step - reward: 0.0134
# 16 episodes - episode_reward: 8.438 [3.000, 15.000] - loss: 0.010 - mae: 1.831 - mean_q: 2.209 - lives: 2.112
#
# Interval 108 (1070000 steps performed)
# 10000/10000 [==============================] - 107s 11ms/step - reward: 0.0135
# 13 episodes - episode_reward: 9.615 [4.000, 17.000] - loss: 0.010 - mae: 1.850 - mean_q: 2.229 - lives: 2.135
#
# Interval 109 (1080000 steps performed)
# 10000/10000 [==============================] - 107s 11ms/step - reward: 0.0152
# 13 episodes - episode_reward: 12.308 [3.000, 22.000] - loss: 0.010 - mae: 1.865 - mean_q: 2.248 - lives: 2.256
#
# Interval 110 (1090000 steps performed)
# 10000/10000 [==============================] - 107s 11ms/step - reward: 0.0135
# 17 episodes - episode_reward: 8.118 [5.000, 12.000] - loss: 0.010 - mae: 1.866 - mean_q: 2.248 - lives: 2.223
#
# Interval 111 (1100000 steps performed)
# 10000/10000 [==============================] - 107s 11ms/step - reward: 0.0141
# 13 episodes - episode_reward: 10.231 [5.000, 16.000] - loss: 0.011 - mae: 1.855 - mean_q: 2.237 - lives: 2.078
#
# Interval 112 (1110000 steps performed)
# 10000/10000 [==============================] - 107s 11ms/step - reward: 0.0127
# 15 episodes - episode_reward: 8.800 [0.000, 16.000] - loss: 0.011 - mae: 1.871 - mean_q: 2.254 - lives: 2.135
#
# Interval 113 (1120000 steps performed)
# 10000/10000 [==============================] - 108s 11ms/step - reward: 0.0135
# 15 episodes - episode_reward: 8.933 [3.000, 24.000] - loss: 0.011 - mae: 1.903 - mean_q: 2.294 - lives: 2.080
#
# Interval 114 (1130000 steps performed)
# 10000/10000 [==============================] - 107s 11ms/step - reward: 0.0134
# 12 episodes - episode_reward: 11.583 [6.000, 19.000] - loss: 0.010 - mae: 1.917 - mean_q: 2.313 - lives: 2.219
#
# Interval 115 (1140000 steps performed)
# 10000/10000 [==============================] - 107s 11ms/step - reward: 0.0148
# 14 episodes - episode_reward: 9.857 [3.000, 22.000] - loss: 0.010 - mae: 1.928 - mean_q: 2.323 - lives: 2.140
#
# Interval 116 (1150000 steps performed)
# 10000/10000 [==============================] - 109s 11ms/step - reward: 0.0144
# 15 episodes - episode_reward: 10.467 [4.000, 18.000] - loss: 0.011 - mae: 1.957 - mean_q: 2.360 - lives: 2.089
#
# Interval 117 (1160000 steps performed)
# 10000/10000 [==============================] - 108s 11ms/step - reward: 0.0125
# 15 episodes - episode_reward: 8.200 [4.000, 14.000] - loss: 0.011 - mae: 1.960 - mean_q: 2.363 - lives: 2.122
#
# Interval 118 (1170000 steps performed)
# 10000/10000 [==============================] - 108s 11ms/step - reward: 0.0136
# 14 episodes - episode_reward: 9.000 [3.000, 18.000] - loss: 0.011 - mae: 1.978 - mean_q: 2.382 - lives: 2.240
#
# Interval 119 (1180000 steps performed)
# 10000/10000 [==============================] - 108s 11ms/step - reward: 0.0142
# 14 episodes - episode_reward: 10.429 [4.000, 22.000] - loss: 0.011 - mae: 1.998 - mean_q: 2.409 - lives: 2.129
#
# Interval 120 (1190000 steps performed)
# 10000/10000 [==============================] - 107s 11ms/step - reward: 0.0150
# 14 episodes - episode_reward: 10.714 [6.000, 17.000] - loss: 0.011 - mae: 2.015 - mean_q: 2.429 - lives: 2.126
#
# Interval 121 (1200000 steps performed)
# 10000/10000 [==============================] - 108s 11ms/step - reward: 0.0142
# 15 episodes - episode_reward: 10.000 [4.000, 17.000] - loss: 0.011 - mae: 2.022 - mean_q: 2.437 - lives: 2.183
#
# Interval 122 (1210000 steps performed)
# 10000/10000 [==============================] - 108s 11ms/step - reward: 0.0144
# 14 episodes - episode_reward: 10.071 [4.000, 19.000] - loss: 0.010 - mae: 2.028 - mean_q: 2.443 - lives: 2.143
#
# Interval 123 (1220000 steps performed)
# 10000/10000 [==============================] - 108s 11ms/step - reward: 0.0154
# 15 episodes - episode_reward: 10.067 [5.000, 28.000] - loss: 0.011 - mae: 2.009 - mean_q: 2.422 - lives: 2.215
#
# Interval 124 (1230000 steps performed)
# 10000/10000 [==============================] - 110s 11ms/step - reward: 0.0143
# 15 episodes - episode_reward: 9.467 [2.000, 21.000] - loss: 0.010 - mae: 2.044 - mean_q: 2.465 - lives: 2.146
#
# Interval 125 (1240000 steps performed)
# 10000/10000 [==============================] - 110s 11ms/step - reward: 0.0122
# 14 episodes - episode_reward: 9.143 [2.000, 24.000] - loss: 0.011 - mae: 2.038 - mean_q: 2.457 - lives: 2.049
#
# Interval 126 (1250000 steps performed)
# 10000/10000 [==============================] - 110s 11ms/step - reward: 0.0130
# 16 episodes - episode_reward: 7.938 [4.000, 14.000] - loss: 0.011 - mae: 2.065 - mean_q: 2.490 - lives: 2.136
#
# Interval 127 (1260000 steps performed)
# 10000/10000 [==============================] - 108s 11ms/step - reward: 0.0146
# 15 episodes - episode_reward: 10.000 [5.000, 17.000] - loss: 0.011 - mae: 2.083 - mean_q: 2.513 - lives: 2.079
#
# Interval 128 (1270000 steps performed)
# 10000/10000 [==============================] - 108s 11ms/step - reward: 0.0143
# 15 episodes - episode_reward: 9.333 [6.000, 19.000] - loss: 0.010 - mae: 2.073 - mean_q: 2.501 - lives: 2.107
#
# Interval 129 (1280000 steps performed)
# 10000/10000 [==============================] - 107s 11ms/step - reward: 0.0133
# 15 episodes - episode_reward: 8.733 [3.000, 15.000] - loss: 0.011 - mae: 2.108 - mean_q: 2.543 - lives: 2.051
#
# Interval 130 (1290000 steps performed)
# 10000/10000 [==============================] - 106s 11ms/step - reward: 0.0134
# 16 episodes - episode_reward: 8.688 [3.000, 19.000] - loss: 0.010 - mae: 2.103 - mean_q: 2.536 - lives: 2.026
#
# Interval 131 (1300000 steps performed)
# 10000/10000 [==============================] - 106s 11ms/step - reward: 0.0130
# 14 episodes - episode_reward: 9.286 [3.000, 16.000] - loss: 0.011 - mae: 2.140 - mean_q: 2.582 - lives: 2.134
#
# Interval 132 (1310000 steps performed)
# 10000/10000 [==============================] - 107s 11ms/step - reward: 0.0146
# 14 episodes - episode_reward: 10.000 [2.000, 21.000] - loss: 0.012 - mae: 2.160 - mean_q: 2.606 - lives: 2.171
#
# Interval 133 (1320000 steps performed)
# 10000/10000 [==============================] - 110s 11ms/step - reward: 0.0159
# 14 episodes - episode_reward: 10.857 [4.000, 21.000] - loss: 0.011 - mae: 2.185 - mean_q: 2.634 - lives: 2.045
#
# Interval 134 (1330000 steps performed)
# 10000/10000 [==============================] - 109s 11ms/step - reward: 0.0134
# 16 episodes - episode_reward: 8.438 [4.000, 17.000] - loss: 0.012 - mae: 2.174 - mean_q: 2.622 - lives: 2.079
#
# Interval 135 (1340000 steps performed)
# 10000/10000 [==============================] - 108s 11ms/step - reward: 0.0135
# 16 episodes - episode_reward: 8.500 [5.000, 13.000] - loss: 0.012 - mae: 2.220 - mean_q: 2.677 - lives: 2.170
#
# Interval 136 (1350000 steps performed)
# 10000/10000 [==============================] - 109s 11ms/step - reward: 0.0139
# 14 episodes - episode_reward: 10.643 [4.000, 19.000] - loss: 0.012 - mae: 2.229 - mean_q: 2.688 - lives: 2.084
#
# Interval 137 (1360000 steps performed)
# 10000/10000 [==============================] - 109s 11ms/step - reward: 0.0136
# 12 episodes - episode_reward: 11.000 [4.000, 21.000] - loss: 0.011 - mae: 2.245 - mean_q: 2.710 - lives: 2.145
#
# Interval 138 (1370000 steps performed)
# 10000/10000 [==============================] - 109s 11ms/step - reward: 0.0142
# 15 episodes - episode_reward: 9.533 [4.000, 16.000] - loss: 0.011 - mae: 2.229 - mean_q: 2.688 - lives: 1.973
#
# Interval 139 (1380000 steps performed)
# 10000/10000 [==============================] - 108s 11ms/step - reward: 0.0123
# 14 episodes - episode_reward: 8.929 [6.000, 16.000] - loss: 0.011 - mae: 2.239 - mean_q: 2.699 - lives: 2.122
#
# Interval 140 (1390000 steps performed)
# 10000/10000 [==============================] - 111s 11ms/step - reward: 0.0139
# 14 episodes - episode_reward: 9.500 [5.000, 20.000] - loss: 0.012 - mae: 2.255 - mean_q: 2.718 - lives: 2.127
#
# Interval 141 (1400000 steps performed)
# 10000/10000 [==============================] - 108s 11ms/step - reward: 0.0139
# 14 episodes - episode_reward: 10.214 [5.000, 14.000] - loss: 0.011 - mae: 2.265 - mean_q: 2.729 - lives: 2.075
#
# Interval 142 (1410000 steps performed)
# 10000/10000 [==============================] - 107s 11ms/step - reward: 0.0151
# 14 episodes - episode_reward: 10.500 [5.000, 24.000] - loss: 0.012 - mae: 2.270 - mean_q: 2.736 - lives: 2.024
#
# Interval 143 (1420000 steps performed)
# 10000/10000 [==============================] - 107s 11ms/step - reward: 0.0159
# 12 episodes - episode_reward: 13.083 [8.000, 25.000] - loss: 0.012 - mae: 2.276 - mean_q: 2.743 - lives: 2.000
#
# Interval 144 (1430000 steps performed)
# 10000/10000 [==============================] - 107s 11ms/step - reward: 0.0133
# 17 episodes - episode_reward: 8.353 [3.000, 16.000] - loss: 0.011 - mae: 2.258 - mean_q: 2.721 - lives: 2.039
#
# Interval 145 (1440000 steps performed)
# 10000/10000 [==============================] - 109s 11ms/step - reward: 0.0156
# 14 episodes - episode_reward: 10.643 [4.000, 18.000] - loss: 0.012 - mae: 2.294 - mean_q: 2.764 - lives: 2.078
#
# Interval 146 (1450000 steps performed)
# 10000/10000 [==============================] - 110s 11ms/step - reward: 0.0138
# 15 episodes - episode_reward: 9.200 [4.000, 16.000] - loss: 0.013 - mae: 2.336 - mean_q: 2.818 - lives: 2.054
#
# Interval 147 (1460000 steps performed)
# 10000/10000 [==============================] - 108s 11ms/step - reward: 0.0152
# 11 episodes - episode_reward: 14.000 [5.000, 29.000] - loss: 0.012 - mae: 2.338 - mean_q: 2.821 - lives: 2.110
#
# Interval 148 (1470000 steps performed)
# 10000/10000 [==============================] - 110s 11ms/step - reward: 0.0156
# 12 episodes - episode_reward: 11.917 [7.000, 17.000] - loss: 0.011 - mae: 2.354 - mean_q: 2.839 - lives: 2.148
#
# Interval 149 (1480000 steps performed)
# 10000/10000 [==============================] - 110s 11ms/step - reward: 0.0145
# 14 episodes - episode_reward: 11.214 [2.000, 22.000] - loss: 0.012 - mae: 2.351 - mean_q: 2.835 - lives: 2.070
#
# Interval 150 (1490000 steps performed)
# 10000/10000 [==============================] - 108s 11ms/step - reward: 0.0152
# 15 episodes - episode_reward: 10.067 [4.000, 18.000] - loss: 0.013 - mae: 2.380 - mean_q: 2.870 - lives: 1.965
#
# Interval 151 (1500000 steps performed)
# 10000/10000 [==============================] - 110s 11ms/step - reward: 0.0140
# 16 episodes - episode_reward: 8.938 [2.000, 15.000] - loss: 0.012 - mae: 2.420 - mean_q: 2.919 - lives: 2.214
#
# Interval 152 (1510000 steps performed)
# 10000/10000 [==============================] - 110s 11ms/step - reward: 0.0150
# 15 episodes - episode_reward: 9.933 [3.000, 16.000] - loss: 0.013 - mae: 2.421 - mean_q: 2.924 - lives: 2.166
#
# Interval 153 (1520000 steps performed)
# 10000/10000 [==============================] - 109s 11ms/step - reward: 0.0152
# 13 episodes - episode_reward: 11.769 [5.000, 20.000] - loss: 0.012 - mae: 2.430 - mean_q: 2.932 - lives: 2.067
#
# Interval 154 (1530000 steps performed)
# 10000/10000 [==============================] - 109s 11ms/step - reward: 0.0131
# 11 episodes - episode_reward: 11.091 [3.000, 16.000] - loss: 0.013 - mae: 2.467 - mean_q: 2.976 - lives: 2.034
#
# Interval 155 (1540000 steps performed)
# 10000/10000 [==============================] - 109s 11ms/step - reward: 0.0152
# 14 episodes - episode_reward: 11.214 [2.000, 25.000] - loss: 0.013 - mae: 2.489 - mean_q: 3.003 - lives: 2.006
#
# Interval 156 (1550000 steps performed)
# 10000/10000 [==============================] - 110s 11ms/step - reward: 0.0138
# 14 episodes - episode_reward: 9.357 [6.000, 16.000] - loss: 0.013 - mae: 2.486 - mean_q: 2.999 - lives: 2.153
#
# Interval 157 (1560000 steps performed)
# 10000/10000 [==============================] - 110s 11ms/step - reward: 0.0148
# 14 episodes - episode_reward: 11.071 [5.000, 18.000] - loss: 0.014 - mae: 2.499 - mean_q: 3.015 - lives: 2.073
#
# Interval 158 (1570000 steps performed)
# 10000/10000 [==============================] - 109s 11ms/step - reward: 0.0143
# 13 episodes - episode_reward: 11.538 [6.000, 21.000] - loss: 0.014 - mae: 2.507 - mean_q: 3.028 - lives: 2.014
#
# Interval 159 (1580000 steps performed)
# 10000/10000 [==============================] - 110s 11ms/step - reward: 0.0156
# 13 episodes - episode_reward: 11.769 [7.000, 23.000] - loss: 0.015 - mae: 2.563 - mean_q: 3.094 - lives: 1.885
#
# Interval 160 (1590000 steps performed)
# 10000/10000 [==============================] - 111s 11ms/step - reward: 0.0131
# 14 episodes - episode_reward: 9.643 [5.000, 15.000] - loss: 0.014 - mae: 2.580 - mean_q: 3.112 - lives: 2.054
#
# Interval 161 (1600000 steps performed)
# 10000/10000 [==============================] - 110s 11ms/step - reward: 0.0156
# 13 episodes - episode_reward: 12.077 [7.000, 20.000] - loss: 0.014 - mae: 2.598 - mean_q: 3.136 - lives: 2.195
#
# Interval 162 (1610000 steps performed)
# 10000/10000 [==============================] - 112s 11ms/step - reward: 0.0145
# 15 episodes - episode_reward: 9.600 [5.000, 23.000] - loss: 0.015 - mae: 2.626 - mean_q: 3.167 - lives: 2.095
#
# Interval 163 (1620000 steps performed)
# 10000/10000 [==============================] - 111s 11ms/step - reward: 0.0140
# 14 episodes - episode_reward: 9.571 [1.000, 18.000] - loss: 0.014 - mae: 2.654 - mean_q: 3.202 - lives: 2.092
#
# Interval 164 (1630000 steps performed)
# 10000/10000 [==============================] - 111s 11ms/step - reward: 0.0168
# 12 episodes - episode_reward: 13.583 [8.000, 25.000] - loss: 0.014 - mae: 2.660 - mean_q: 3.208 - lives: 2.191
#
# Interval 165 (1640000 steps performed)
# 10000/10000 [==============================] - 111s 11ms/step - reward: 0.0136
# 16 episodes - episode_reward: 8.750 [3.000, 18.000] - loss: 0.015 - mae: 2.686 - mean_q: 3.240 - lives: 2.163
#
# Interval 166 (1650000 steps performed)
# 10000/10000 [==============================] - 111s 11ms/step - reward: 0.0133
# 15 episodes - episode_reward: 9.000 [3.000, 25.000] - loss: 0.016 - mae: 2.673 - mean_q: 3.221 - lives: 2.103
#
# Interval 167 (1660000 steps performed)
# 10000/10000 [==============================] - 111s 11ms/step - reward: 0.0137
# 13 episodes - episode_reward: 10.538 [7.000, 18.000] - loss: 0.013 - mae: 2.707 - mean_q: 3.263 - lives: 1.978
#
# Interval 168 (1670000 steps performed)
# 10000/10000 [==============================] - 112s 11ms/step - reward: 0.0142
# 14 episodes - episode_reward: 10.429 [5.000, 23.000] - loss: 0.013 - mae: 2.680 - mean_q: 3.229 - lives: 2.148
#
# Interval 169 (1680000 steps performed)
# 10000/10000 [==============================] - 113s 11ms/step - reward: 0.0131
# 15 episodes - episode_reward: 8.200 [4.000, 13.000] - loss: 0.016 - mae: 2.693 - mean_q: 3.245 - lives: 2.198
#
# Interval 170 (1690000 steps performed)
# 10000/10000 [==============================] - 113s 11ms/step - reward: 0.0144
# 15 episodes - episode_reward: 9.867 [5.000, 19.000] - loss: 0.014 - mae: 2.698 - mean_q: 3.253 - lives: 2.187
#
# Interval 171 (1700000 steps performed)
# 10000/10000 [==============================] - 113s 11ms/step - reward: 0.0129
# 14 episodes - episode_reward: 9.286 [4.000, 17.000] - loss: 0.015 - mae: 2.691 - mean_q: 3.242 - lives: 2.141
#
# Interval 172 (1710000 steps performed)
# 10000/10000 [==============================] - 112s 11ms/step - reward: 0.0133
# 14 episodes - episode_reward: 8.429 [3.000, 23.000] - loss: 0.015 - mae: 2.724 - mean_q: 3.282 - lives: 2.172
#
# Interval 173 (1720000 steps performed)
# 10000/10000 [==============================] - 113s 11ms/step - reward: 0.0133
# 16 episodes - episode_reward: 9.562 [4.000, 21.000] - loss: 0.014 - mae: 2.748 - mean_q: 3.316 - lives: 2.121
#
# Interval 174 (1730000 steps performed)
# 10000/10000 [==============================] - 112s 11ms/step - reward: 0.0132
# 14 episodes - episode_reward: 8.714 [5.000, 16.000] - loss: 0.014 - mae: 2.768 - mean_q: 3.338 - lives: 2.117
#
# Interval 175 (1740000 steps performed)
# 10000/10000 [==============================] - 112s 11ms/step - reward: 0.0146
# 15 episodes - episode_reward: 9.200 [1.000, 18.000] - loss: 0.016 - mae: 2.781 - mean_q: 3.359 - lives: 2.066
#
# Interval 176 (1750000 steps performed)
# 10000/10000 [==============================] - 113s 11ms/step - reward: 0.0140
# 15 episodes - episode_reward: 10.533 [5.000, 22.000] - loss: 0.015 - mae: 2.805 - mean_q: 3.384 - lives: 1.980
#
# Interval 177 (1760000 steps performed)
# 10000/10000 [==============================] - 112s 11ms/step - reward: 0.0167
# 14 episodes - episode_reward: 11.286 [6.000, 18.000] - loss: 0.016 - mae: 2.840 - mean_q: 3.424 - lives: 2.120
#
# Interval 178 (1770000 steps performed)
# 10000/10000 [==============================] - 111s 11ms/step - reward: 0.0141
# 16 episodes - episode_reward: 9.375 [4.000, 17.000] - loss: 0.014 - mae: 2.832 - mean_q: 3.414 - lives: 2.089
#
# Interval 179 (1780000 steps performed)
# 10000/10000 [==============================] - 112s 11ms/step - reward: 0.0140
# 17 episodes - episode_reward: 7.882 [2.000, 17.000] - loss: 0.013 - mae: 2.836 - mean_q: 3.421 - lives: 2.117
#
# Interval 180 (1790000 steps performed)
# 10000/10000 [==============================] - 112s 11ms/step - reward: 0.0142
# 14 episodes - episode_reward: 10.143 [4.000, 18.000] - loss: 0.014 - mae: 2.858 - mean_q: 3.449 - lives: 2.053
#
# Interval 181 (1800000 steps performed)
# 10000/10000 [==============================] - 112s 11ms/step - reward: 0.0159
# 13 episodes - episode_reward: 12.692 [7.000, 21.000] - loss: 0.015 - mae: 2.879 - mean_q: 3.475 - lives: 2.188
#
# Interval 182 (1810000 steps performed)
# 10000/10000 [==============================] - 112s 11ms/step - reward: 0.0147
# 13 episodes - episode_reward: 11.308 [5.000, 26.000] - loss: 0.015 - mae: 2.875 - mean_q: 3.469 - lives: 1.952
#
# Interval 183 (1820000 steps performed)
# 10000/10000 [==============================] - 112s 11ms/step - reward: 0.0151
# 16 episodes - episode_reward: 9.000 [5.000, 17.000] - loss: 0.016 - mae: 2.910 - mean_q: 3.513 - lives: 2.171
#
# Interval 184 (1830000 steps performed)
# 10000/10000 [==============================] - 111s 11ms/step - reward: 0.0139
# 16 episodes - episode_reward: 8.812 [4.000, 14.000] - loss: 0.014 - mae: 2.911 - mean_q: 3.513 - lives: 2.049
#
# Interval 185 (1840000 steps performed)
# 10000/10000 [==============================] - 111s 11ms/step - reward: 0.0142
# 16 episodes - episode_reward: 8.812 [4.000, 14.000] - loss: 0.015 - mae: 2.911 - mean_q: 3.512 - lives: 2.107
#
# Interval 186 (1850000 steps performed)
# 10000/10000 [==============================] - 113s 11ms/step - reward: 0.0142
# 13 episodes - episode_reward: 9.462 [3.000, 20.000] - loss: 0.016 - mae: 2.935 - mean_q: 3.542 - lives: 2.059
#
# Interval 187 (1860000 steps performed)
# 10000/10000 [==============================] - 111s 11ms/step - reward: 0.0147
# 14 episodes - episode_reward: 12.286 [4.000, 25.000] - loss: 0.015 - mae: 2.931 - mean_q: 3.541 - lives: 1.984
#
# Interval 188 (1870000 steps performed)
# 10000/10000 [==============================] - 112s 11ms/step - reward: 0.0133
# 15 episodes - episode_reward: 8.867 [3.000, 21.000] - loss: 0.016 - mae: 2.922 - mean_q: 3.526 - lives: 2.123
#
# Interval 189 (1880000 steps performed)
# 10000/10000 [==============================] - 113s 11ms/step - reward: 0.0135
# 14 episodes - episode_reward: 9.571 [2.000, 18.000] - loss: 0.015 - mae: 2.930 - mean_q: 3.537 - lives: 2.065
#
# Interval 190 (1890000 steps performed)
# 10000/10000 [==============================] - 112s 11ms/step - reward: 0.0144
# 15 episodes - episode_reward: 9.400 [2.000, 19.000] - loss: 0.017 - mae: 2.949 - mean_q: 3.558 - lives: 2.152
#
# Interval 191 (1900000 steps performed)
# 10000/10000 [==============================] - 112s 11ms/step - reward: 0.0159
# 13 episodes - episode_reward: 11.077 [3.000, 19.000] - loss: 0.016 - mae: 2.971 - mean_q: 3.586 - lives: 2.128
#
# Interval 192 (1910000 steps performed)
# 10000/10000 [==============================] - 112s 11ms/step - reward: 0.0137
# 17 episodes - episode_reward: 8.765 [2.000, 20.000] - loss: 0.016 - mae: 2.998 - mean_q: 3.616 - lives: 2.105
#
# Interval 193 (1920000 steps performed)
# 10000/10000 [==============================] - 114s 11ms/step - reward: 0.0137
# 16 episodes - episode_reward: 9.000 [5.000, 31.000] - loss: 0.015 - mae: 2.986 - mean_q: 3.603 - lives: 2.017
#
# Interval 194 (1930000 steps performed)
# 10000/10000 [==============================] - 112s 11ms/step - reward: 0.0126
# 14 episodes - episode_reward: 9.000 [5.000, 14.000] - loss: 0.016 - mae: 3.004 - mean_q: 3.622 - lives: 1.971
#
# Interval 195 (1940000 steps performed)
# 10000/10000 [==============================] - 112s 11ms/step - reward: 0.0147
# 14 episodes - episode_reward: 9.929 [5.000, 16.000] - loss: 0.015 - mae: 2.997 - mean_q: 3.615 - lives: 2.190
#
# Interval 196 (1950000 steps performed)
# 10000/10000 [==============================] - 114s 11ms/step - reward: 0.0145
# 17 episodes - episode_reward: 8.471 [5.000, 18.000] - loss: 0.015 - mae: 3.036 - mean_q: 3.662 - lives: 2.076
#
# Interval 197 (1960000 steps performed)
# 10000/10000 [==============================] - 113s 11ms/step - reward: 0.0147
# 14 episodes - episode_reward: 10.857 [7.000, 18.000] - loss: 0.017 - mae: 3.047 - mean_q: 3.677 - lives: 2.111
#
# Interval 198 (1970000 steps performed)
# 10000/10000 [==============================] - 114s 11ms/step - reward: 0.0133
# 14 episodes - episode_reward: 9.357 [5.000, 15.000] - loss: 0.017 - mae: 3.021 - mean_q: 3.644 - lives: 2.125
#
# Interval 199 (1980000 steps performed)
# 10000/10000 [==============================] - 114s 11ms/step - reward: 0.0151
# 15 episodes - episode_reward: 10.133 [4.000, 21.000] - loss: 0.017 - mae: 3.067 - mean_q: 3.700 - lives: 2.216
#
# Interval 200 (1990000 steps performed)
# 10000/10000 [==============================] - 113s 11ms/step - reward: 0.0142
# done, took 19972.063 seconds

# %%
# use PyvirtualDisplay to create a “virtual display” that we will send our rendered frames to
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()

# %%
# wrap a Monitor around environment
env_monitor = wrap_env(env)

# %%
# Testing part to calculate the mean reward
weights_filename = BASE_FOLDER+'dqn2_boltz_{}_weights.h5f'.format(env_name)
dqn.load_weights(weights_filename)
dqn.test(env_monitor, nb_episodes=10, visualize=True)
show_video()
# Out:
# Testing for 10 episodes ...
# Episode 1: reward: 12.000, steps: 690
# Episode 2: reward: 21.000, steps: 986
# Episode 3: reward: 10.000, steps: 696
# Episode 4: reward: 13.000, steps: 937
# Episode 5: reward: 9.000, steps: 399
# Episode 6: reward: 18.000, steps: 1048
# Episode 7: reward: 9.000, steps: 528
# Episode 8: reward: 12.000, steps: 708
# Episode 9: reward: 20.000, steps: 936
# Episode 10: reward: 7.000, steps: 464
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# 3) Justificación de los parámetros seleccionados y de los resultados obtenidos
