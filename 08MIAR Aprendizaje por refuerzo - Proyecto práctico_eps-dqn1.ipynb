# %% [markdown]
# ### Proyecto práctico

# %% [markdown]
# Consideraciones a tener en cuenta:
#
# - El entorno sobre el que trabajaremos será _SpaceInvaders-v0_ y el algoritmo que usaremos será _DQN_.
#
# - Para nuestro ejercicio, una solución óptima será alcanzada cuando el agente consiga una **media de recompensa por encima de 20 puntos en modo test**. Por ello, esta media de la recompensa se calculará a partir del código de test en la última celda del notebook.

# %% [markdown]
# Este proyecto práctico consta de tres partes:
#
#    1) Implementar la red neuronal que se usará en la solución
#
#    2) Implementar las distintas piezas de la solución DQN
#
#    3) Justificar la respuesta en relación a los resultados obtenidos

# %% [markdown]
# IMPORTANTE:
#
# - Si no se consigue una puntuación óptima, responder sobre la mejor puntuación obtenida.
#
# - Para entrenamientos largos, recordad que podéis usar checkpoints de vuestros modelos para retomar los entrenamientos. En este caso, recordad cambiar los parámetros adecuadamente (sobre todo los relacionados con el proceso de exploración).
#
# - Tened en cuenta que las versiones de librerías recomendadas son Tensorflow==1.13.1, Keras==2.2.4 y keras-rl==0.4.2

# %% [markdown]
# #### Preparar entorno sobre TF2

# %%
# Conectamos con nuestro Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Establezco una ruta absoluta a un directorio existente de mi Google Drive (cambiar a drive propio)
BASE_FOLDER = "/content/drive/Othercomputers/My MacBook Pro/08_aprendizaje_por_refuerzo/proyecto/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# install keras-rl2 that works with tensorflow 2.x
# !pip install keras-rl2 > /dev/null 2>&1

# install gym and atari ROMs
# !pip install -U gym>=0.21.0
# !pip install -U gym[atari,accept-rom-license]
# Out:
# Requirement already satisfied: gym[accept-rom-license,atari] in /usr/local/lib/python3.7/dist-packages (0.21.0)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.7/dist-packages (from gym[accept-rom-license,atari]) (1.19.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym[accept-rom-license,atari]) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.8.1 in /usr/local/lib/python3.7/dist-packages (from gym[accept-rom-license,atari]) (4.8.2)
# Requirement already satisfied: autorom[accept-rom-license]~=0.4.2 in /usr/local/lib/python3.7/dist-packages (from gym[accept-rom-license,atari]) (0.4.2)
# Requirement already satisfied: ale-py~=0.7.1 in /usr/local/lib/python3.7/dist-packages (from gym[accept-rom-license,atari]) (0.7.3)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from ale-py~=0.7.1->gym[accept-rom-license,atari]) (5.4.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (4.62.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (2.23.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (7.1.2)
# Requirement already satisfied: AutoROM.accept-rom-license in /usr/local/lib/python3.7/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (0.4.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.8.1->gym[accept-rom-license,atari]) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.8.1->gym[accept-rom-license,atari]) (3.10.0.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (2021.10.8)

# %%
# install the relevant libraries to make rendering possible
# !pip install pyvirtualdisplay > /dev/null 2>&1
# !apt-get update
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:2 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Ign:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Ign:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:9 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Reading package lists... Done

# %%
# import the relevant libraries 
import gym
from gym import logger as gymlogger
from gym.wrappers import Monitor
gymlogger.set_level(40) #error only
import tensorflow as tf
import numpy as np
import math
import glob
import io
import base64
from IPython.display import HTML

from IPython import display as ipythondisplay
# Out:
# /usr/local/lib/python3.7/dist-packages/ale_py/roms/utils.py:90: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for external in metadata.entry_points().get(self.group, []):

# %%
"""
Utility functions to enable video recording of gym environment and displaying it
To enable video, just do "env = wrap_env(env)""
"""

def show_video():
  mp4list = glob.glob('video/*.mp4')
  if len(mp4list) > 0:
    mp4 = mp4list[0]
    video = io.open(mp4, 'r+b').read()
    encoded = base64.b64encode(video)
    ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
  else: 
    print("Could not find video")
    

def wrap_env(env):
  env = Monitor(env, './video', force=True)
  return env

# %% [markdown]
# #### Importar librerías

# %%
from __future__ import division

from PIL import Image
import numpy as np
import gym

from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Convolution2D, Permute, Dropout, BatchNormalization
#from keras.optimizers import Adam
from tensorflow.keras.optimizers import Adam
import keras.backend as K

from rl.agents.dqn import DQNAgent
from rl.policy import LinearAnnealedPolicy, BoltzmannQPolicy, EpsGreedyQPolicy
from rl.memory import SequentialMemory
from rl.core import Processor
from rl.callbacks import FileLogger, ModelIntervalCheckpoint

# %% [markdown]
# #### Configuración base

# %%
INPUT_SHAPE = (84, 84)
WINDOW_LENGTH = 4

env_name = 'SpaceInvaders-v0'
#env = wrap_env(gym.make(env_name))
env = gym.make(env_name)

np.random.seed(123)
env.seed(123)
nb_actions = env.action_space.n

# %%
class AtariProcessor(Processor):
    def process_observation(self, observation):
        assert observation.ndim == 3  # (height, width, channel)
        img = Image.fromarray(observation)
        img = img.resize(INPUT_SHAPE).convert('L') # a escala de grises
        processed_observation = np.array(img)
        assert processed_observation.shape == INPUT_SHAPE
        return processed_observation.astype('uint8') # casting a 8 bits

    def process_state_batch(self, batch):
        processed_batch = batch.astype('float32') / 255. # normalizar entre 0 y 1
        return processed_batch

    def process_reward(self, reward):
        return np.clip(reward, -1., 1.) # se acota para que no sea tan sensible a valores extremos

# %%
# Acciones disponibles en el entorno
nb_actions = env.action_space.n
nb_actions
# Out:
# 6

# %%
# Nombres de las acciones
env.unwrapped.get_action_meanings()
# Out:
# ['NOOP', 'FIRE', 'RIGHT', 'LEFT', 'RIGHTFIRE', 'LEFTFIRE']

# %%
# Dimensions de las observaciones del entorno
env.observation_space.shape
# Out:
# (210, 160, 3)

# %% [markdown]
# 1) Implementación de la red neuronal

# %%
# Next, we build our model. We use the same model that was described by Mnih et al. (2015).
input_shape = (WINDOW_LENGTH,) + INPUT_SHAPE
model = Sequential()

# segun el backend, se usa un ordenamiento de dimensiones diferente (para tensorflow o theano)
#if K.image_dim_ordering() == 'tf':
if K.image_data_format() == 'channels_last':
    # (width, height, channels)
    model.add(Permute((2, 3, 1), input_shape=input_shape))
#elif K.image_dim_ordering() == 'th':
elif image_data_format() == 'channels_first':
    # (channels, width, height)
    model.add(Permute((1, 2, 3), input_shape=input_shape))
else:
    raise RuntimeError('Unknown image_dim_ordering.')
# conv_1
model.add(Convolution2D(32, (8, 8), strides=(4, 4)))
model.add(Activation('relu'))
# conv_2
model.add(Convolution2D(64, (4, 4), strides=(2, 2)))
model.add(Activation('relu'))
# conv_3
model.add(Convolution2D(64, (3, 3), strides=(1, 1)))
model.add(Activation('relu'))
# FC
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dense(nb_actions))
model.add(Activation('linear')) # lineal porque son las recompensas esperadas a futuro para cada accion (nb_actions)
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  permute (Permute)           (None, 84, 84, 4)         0
#
#  conv2d (Conv2D)             (None, 20, 20, 32)        8224
#
#  activation (Activation)     (None, 20, 20, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 9, 9, 64)          32832
#
#  activation_1 (Activation)   (None, 9, 9, 64)          0
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 64)          36928
#
#  activation_2 (Activation)   (None, 7, 7, 64)          0
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 512)               1606144
#
#  activation_3 (Activation)   (None, 512)               0
#
#  dense_1 (Dense)             (None, 6)                 3078
#
#  activation_4 (Activation)   (None, 6)                 0
#
# =================================================================
# Total params: 1,687,206
# Trainable params: 1,687,206
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# 2) Implementación de la solución DQN

# %%
memory = SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH)
processor = AtariProcessor()

# %%
# nb_steps será el tiempo que durará la exploración, antes de pasar a explotación. 
# value_test guarda un pelín de aleatoriedad para minimizar el riesgo de estancamiento en minimos durante el test
# empieza muy aleatorio a 1 (100%) de acciones aleatorias y va decreciendo a más acciones 'predichas/aprendidas'
policy = LinearAnnealedPolicy(EpsGreedyQPolicy(), attr='eps',
                              value_max=1., value_min=.1, value_test=.05,
                              nb_steps=2000000)

# %%
# recordar que el modelo se 'duplica' uno para target y otro para predicción, ambos idénticos
# gamma es el discount factor de las rewards
# target se actualiza cada 10000 steps
# cada 20 steps, se actualizan los pesos del modelo
# bajamos el learning rate
dqn = DQNAgent(model=model, nb_actions=nb_actions, policy=policy,
               memory=memory, processor=processor,
               nb_steps_warmup=50000, gamma=.9,
               target_model_update=10000,
               train_interval=20)
dqn.compile(Adam(learning_rate=.00025), metrics=['mae'])

# %%
# Training part
# log en pantalla cada 10,000 steps
# cada 250000 steps almaceno versiones del modelo (callbacks)
# el log escrito, cada 100 steps
weights_filename = BASE_FOLDER+'dqn2_{}_weights.h5f'.format(env_name)
checkpoint_weights_filename = BASE_FOLDER+'dqn2_' + env_name + '_weights_{step}.h5f'
log_filename = BASE_FOLDER+'dqn2_{}_log.json'.format(env_name)
callbacks = [ModelIntervalCheckpoint(checkpoint_weights_filename, interval=500000)]
callbacks += [FileLogger(log_filename, interval=100)]

dqn.fit(env, callbacks=callbacks, nb_steps=3000000, log_interval=10000, visualize=False)

dqn.save_weights(weights_filename, overwrite=True)
# Out:
# Training for 3000000 steps ...
# Interval 1 (0 steps performed)
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 10000/10000 [==============================] - 47s 4ms/step - reward: 0.0131
# 14 episodes - episode_reward: 9.000 [4.000, 18.000] - lives: 2.223
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 36s 4ms/step - reward: 0.0141
# 16 episodes - episode_reward: 8.938 [5.000, 16.000] - lives: 2.090
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 35s 4ms/step - reward: 0.0140
# 14 episodes - episode_reward: 9.929 [5.000, 17.000] - lives: 2.034
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 35s 3ms/step - reward: 0.0127
# 14 episodes - episode_reward: 8.929 [5.000, 14.000] - lives: 2.113
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 36s 4ms/step - reward: 0.0129
# 13 episodes - episode_reward: 9.923 [3.000, 18.000] - lives: 2.102
#
# Interval 6 (50000 steps performed)
#    16/10000 [..............................] - ETA: 33s - reward: 0.0000e+00
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 10000/10000 [==============================] - 69s 7ms/step - reward: 0.0134
# 16 episodes - episode_reward: 8.562 [3.000, 21.000] - loss: 0.006 - mae: 0.022 - mean_q: 0.034 - mean_eps: 0.975 - lives: 2.215
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 68s 7ms/step - reward: 0.0139
# 14 episodes - episode_reward: 9.357 [5.000, 19.000] - loss: 0.007 - mae: 0.039 - mean_q: 0.052 - mean_eps: 0.971 - lives: 2.153
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 69s 7ms/step - reward: 0.0144
# 14 episodes - episode_reward: 11.000 [6.000, 23.000] - loss: 0.007 - mae: 0.053 - mean_q: 0.069 - mean_eps: 0.966 - lives: 2.080
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: 0.0143
# 15 episodes - episode_reward: 9.067 [4.000, 15.000] - loss: 0.006 - mae: 0.068 - mean_q: 0.088 - mean_eps: 0.962 - lives: 2.089
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 69s 7ms/step - reward: 0.0140
# 12 episodes - episode_reward: 11.917 [3.000, 26.000] - loss: 0.007 - mae: 0.085 - mean_q: 0.108 - mean_eps: 0.957 - lives: 2.155
#
# Interval 11 (100000 steps performed)
# 10000/10000 [==============================] - 69s 7ms/step - reward: 0.0127
# 14 episodes - episode_reward: 8.857 [4.000, 15.000] - loss: 0.006 - mae: 0.086 - mean_q: 0.110 - mean_eps: 0.953 - lives: 1.996
#
# Interval 12 (110000 steps performed)
# 10000/10000 [==============================] - 69s 7ms/step - reward: 0.0140
# 15 episodes - episode_reward: 9.467 [5.000, 22.000] - loss: 0.007 - mae: 0.099 - mean_q: 0.122 - mean_eps: 0.948 - lives: 2.041
#
# Interval 13 (120000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: 0.0123
# 15 episodes - episode_reward: 8.267 [2.000, 15.000] - loss: 0.006 - mae: 0.105 - mean_q: 0.131 - mean_eps: 0.944 - lives: 1.969
#
# Interval 14 (130000 steps performed)
# 10000/10000 [==============================] - 69s 7ms/step - reward: 0.0135
# 17 episodes - episode_reward: 8.235 [4.000, 14.000] - loss: 0.007 - mae: 0.117 - mean_q: 0.145 - mean_eps: 0.939 - lives: 2.044
#
# Interval 15 (140000 steps performed)
# 10000/10000 [==============================] - 69s 7ms/step - reward: 0.0129
# 13 episodes - episode_reward: 9.769 [5.000, 20.000] - loss: 0.007 - mae: 0.121 - mean_q: 0.150 - mean_eps: 0.935 - lives: 2.154
#
# Interval 16 (150000 steps performed)
# 10000/10000 [==============================] - 69s 7ms/step - reward: 0.0149
# 14 episodes - episode_reward: 10.500 [3.000, 19.000] - loss: 0.007 - mae: 0.126 - mean_q: 0.155 - mean_eps: 0.930 - lives: 2.096
#
# Interval 17 (160000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: 0.0120
# 14 episodes - episode_reward: 8.571 [4.000, 15.000] - loss: 0.007 - mae: 0.125 - mean_q: 0.155 - mean_eps: 0.926 - lives: 2.038
#
# Interval 18 (170000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: 0.0134
# 14 episodes - episode_reward: 9.571 [6.000, 14.000] - loss: 0.006 - mae: 0.131 - mean_q: 0.162 - mean_eps: 0.921 - lives: 2.134
#
# Interval 19 (180000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: 0.0166
# 12 episodes - episode_reward: 12.750 [5.000, 28.000] - loss: 0.007 - mae: 0.129 - mean_q: 0.160 - mean_eps: 0.917 - lives: 2.057
#
# Interval 20 (190000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: 0.0134
# 15 episodes - episode_reward: 10.067 [4.000, 20.000] - loss: 0.006 - mae: 0.131 - mean_q: 0.163 - mean_eps: 0.912 - lives: 2.098
#
# Interval 21 (200000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: 0.0137
# 14 episodes - episode_reward: 9.500 [3.000, 23.000] - loss: 0.007 - mae: 0.147 - mean_q: 0.179 - mean_eps: 0.908 - lives: 2.081
#
# Interval 22 (210000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: 0.0149
# 12 episodes - episode_reward: 12.750 [6.000, 34.000] - loss: 0.007 - mae: 0.160 - mean_q: 0.197 - mean_eps: 0.903 - lives: 2.042
#
# Interval 23 (220000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: 0.0134
# 15 episodes - episode_reward: 8.333 [3.000, 17.000] - loss: 0.006 - mae: 0.173 - mean_q: 0.213 - mean_eps: 0.899 - lives: 2.145
#
# Interval 24 (230000 steps performed)
# 10000/10000 [==============================] - 71s 7ms/step - reward: 0.0133
# 15 episodes - episode_reward: 9.133 [5.000, 15.000] - loss: 0.006 - mae: 0.170 - mean_q: 0.211 - mean_eps: 0.894 - lives: 2.075
#
# Interval 25 (240000 steps performed)
# 10000/10000 [==============================] - 72s 7ms/step - reward: 0.0131
# 15 episodes - episode_reward: 9.000 [5.000, 22.000] - loss: 0.007 - mae: 0.170 - mean_q: 0.209 - mean_eps: 0.890 - lives: 2.146
#
# Interval 26 (250000 steps performed)
# 10000/10000 [==============================] - 71s 7ms/step - reward: 0.0146
# 14 episodes - episode_reward: 10.143 [4.000, 17.000] - loss: 0.006 - mae: 0.175 - mean_q: 0.215 - mean_eps: 0.885 - lives: 2.093
#
# Interval 27 (260000 steps performed)
# 10000/10000 [==============================] - 72s 7ms/step - reward: 0.0144
# 14 episodes - episode_reward: 10.214 [4.000, 22.000] - loss: 0.006 - mae: 0.183 - mean_q: 0.225 - mean_eps: 0.881 - lives: 2.198
#
# Interval 28 (270000 steps performed)
# 10000/10000 [==============================] - 71s 7ms/step - reward: 0.0152
# 14 episodes - episode_reward: 10.643 [4.000, 29.000] - loss: 0.007 - mae: 0.186 - mean_q: 0.229 - mean_eps: 0.876 - lives: 1.988
#
# Interval 29 (280000 steps performed)
# 10000/10000 [==============================] - 72s 7ms/step - reward: 0.0150
# 14 episodes - episode_reward: 10.857 [5.000, 30.000] - loss: 0.007 - mae: 0.205 - mean_q: 0.251 - mean_eps: 0.872 - lives: 2.029
#
# Interval 30 (290000 steps performed)
# 10000/10000 [==============================] - 71s 7ms/step - reward: 0.0129
# 13 episodes - episode_reward: 10.385 [5.000, 17.000] - loss: 0.008 - mae: 0.217 - mean_q: 0.265 - mean_eps: 0.867 - lives: 2.002
#
# Interval 31 (300000 steps performed)
# 10000/10000 [==============================] - 72s 7ms/step - reward: 0.0162
# 17 episodes - episode_reward: 9.471 [4.000, 19.000] - loss: 0.007 - mae: 0.215 - mean_q: 0.264 - mean_eps: 0.863 - lives: 2.203
#
# Interval 32 (310000 steps performed)
# 10000/10000 [==============================] - 72s 7ms/step - reward: 0.0143
# 15 episodes - episode_reward: 9.267 [4.000, 18.000] - loss: 0.007 - mae: 0.210 - mean_q: 0.257 - mean_eps: 0.858 - lives: 2.093
#
# Interval 33 (320000 steps performed)
# 10000/10000 [==============================] - 73s 7ms/step - reward: 0.0135
# 16 episodes - episode_reward: 8.625 [4.000, 19.000] - loss: 0.007 - mae: 0.218 - mean_q: 0.265 - mean_eps: 0.854 - lives: 2.121
#
# Interval 34 (330000 steps performed)
# 10000/10000 [==============================] - 73s 7ms/step - reward: 0.0129
# 15 episodes - episode_reward: 8.400 [5.000, 13.000] - loss: 0.008 - mae: 0.226 - mean_q: 0.277 - mean_eps: 0.849 - lives: 2.128
#
# Interval 35 (340000 steps performed)
# 10000/10000 [==============================] - 73s 7ms/step - reward: 0.0135
# 14 episodes - episode_reward: 10.071 [5.000, 18.000] - loss: 0.007 - mae: 0.216 - mean_q: 0.265 - mean_eps: 0.845 - lives: 2.062
#
# Interval 36 (350000 steps performed)
# 10000/10000 [==============================] - 74s 7ms/step - reward: 0.0176
# 12 episodes - episode_reward: 12.750 [5.000, 23.000] - loss: 0.006 - mae: 0.223 - mean_q: 0.274 - mean_eps: 0.840 - lives: 2.034
#
# Interval 37 (360000 steps performed)
# 10000/10000 [==============================] - 74s 7ms/step - reward: 0.0137
# 15 episodes - episode_reward: 10.333 [3.000, 23.000] - loss: 0.007 - mae: 0.218 - mean_q: 0.266 - mean_eps: 0.836 - lives: 2.159
#
# Interval 38 (370000 steps performed)
# 10000/10000 [==============================] - 74s 7ms/step - reward: 0.0147
# 14 episodes - episode_reward: 10.071 [5.000, 28.000] - loss: 0.007 - mae: 0.219 - mean_q: 0.265 - mean_eps: 0.831 - lives: 2.095
#
# Interval 39 (380000 steps performed)
# 10000/10000 [==============================] - 74s 7ms/step - reward: 0.0152
# 14 episodes - episode_reward: 10.929 [5.000, 21.000] - loss: 0.007 - mae: 0.218 - mean_q: 0.265 - mean_eps: 0.827 - lives: 2.047
#
# Interval 40 (390000 steps performed)
# 10000/10000 [==============================] - 75s 7ms/step - reward: 0.0130
# 15 episodes - episode_reward: 9.200 [2.000, 18.000] - loss: 0.006 - mae: 0.212 - mean_q: 0.258 - mean_eps: 0.822 - lives: 2.044
#
# Interval 41 (400000 steps performed)
# 10000/10000 [==============================] - 75s 7ms/step - reward: 0.0141
# 15 episodes - episode_reward: 9.533 [3.000, 18.000] - loss: 0.006 - mae: 0.220 - mean_q: 0.269 - mean_eps: 0.818 - lives: 2.124
#
# Interval 42 (410000 steps performed)
# 10000/10000 [==============================] - 75s 7ms/step - reward: 0.0131
# 13 episodes - episode_reward: 9.538 [5.000, 20.000] - loss: 0.007 - mae: 0.229 - mean_q: 0.278 - mean_eps: 0.813 - lives: 2.131
#
# Interval 43 (420000 steps performed)
# 10000/10000 [==============================] - 75s 7ms/step - reward: 0.0137
# 13 episodes - episode_reward: 11.077 [4.000, 22.000] - loss: 0.007 - mae: 0.216 - mean_q: 0.263 - mean_eps: 0.809 - lives: 2.091
#
# Interval 44 (430000 steps performed)
# 10000/10000 [==============================] - 76s 8ms/step - reward: 0.0159
# 15 episodes - episode_reward: 10.267 [4.000, 23.000] - loss: 0.007 - mae: 0.219 - mean_q: 0.267 - mean_eps: 0.804 - lives: 2.104
#
# Interval 45 (440000 steps performed)
# 10000/10000 [==============================] - 75s 7ms/step - reward: 0.0139
# 13 episodes - episode_reward: 11.077 [6.000, 23.000] - loss: 0.006 - mae: 0.218 - mean_q: 0.265 - mean_eps: 0.800 - lives: 2.184
#
# Interval 46 (450000 steps performed)
# 10000/10000 [==============================] - 75s 7ms/step - reward: 0.0166
# 14 episodes - episode_reward: 11.786 [9.000, 15.000] - loss: 0.006 - mae: 0.207 - mean_q: 0.252 - mean_eps: 0.795 - lives: 2.156
#
# Interval 47 (460000 steps performed)
# 10000/10000 [==============================] - 76s 8ms/step - reward: 0.0151
# 15 episodes - episode_reward: 9.800 [4.000, 15.000] - loss: 0.006 - mae: 0.205 - mean_q: 0.251 - mean_eps: 0.791 - lives: 1.977
#
# Interval 48 (470000 steps performed)
# 10000/10000 [==============================] - 77s 8ms/step - reward: 0.0158
# 15 episodes - episode_reward: 10.867 [4.000, 18.000] - loss: 0.007 - mae: 0.200 - mean_q: 0.244 - mean_eps: 0.786 - lives: 2.180
#
# Interval 49 (480000 steps performed)
# 10000/10000 [==============================] - 77s 8ms/step - reward: 0.0164
# 16 episodes - episode_reward: 9.500 [2.000, 24.000] - loss: 0.006 - mae: 0.207 - mean_q: 0.252 - mean_eps: 0.782 - lives: 2.052
#
# Interval 50 (490000 steps performed)
# 10000/10000 [==============================] - 76s 8ms/step - reward: 0.0161
# 14 episodes - episode_reward: 11.429 [4.000, 20.000] - loss: 0.007 - mae: 0.210 - mean_q: 0.255 - mean_eps: 0.777 - lives: 2.145
#
# Interval 51 (500000 steps performed)
# 10000/10000 [==============================] - 77s 8ms/step - reward: 0.0161
# 16 episodes - episode_reward: 10.562 [3.000, 26.000] - loss: 0.007 - mae: 0.207 - mean_q: 0.251 - mean_eps: 0.773 - lives: 2.092
#
# Interval 52 (510000 steps performed)
# 10000/10000 [==============================] - 78s 8ms/step - reward: 0.0141
# 12 episodes - episode_reward: 11.667 [4.000, 19.000] - loss: 0.007 - mae: 0.215 - mean_q: 0.259 - mean_eps: 0.768 - lives: 1.986
#
# Interval 53 (520000 steps performed)
# 10000/10000 [==============================] - 78s 8ms/step - reward: 0.0138
# 18 episodes - episode_reward: 7.611 [3.000, 13.000] - loss: 0.007 - mae: 0.225 - mean_q: 0.274 - mean_eps: 0.764 - lives: 2.073
#
# Interval 54 (530000 steps performed)
# 10000/10000 [==============================] - 78s 8ms/step - reward: 0.0122
# 17 episodes - episode_reward: 7.588 [3.000, 13.000] - loss: 0.007 - mae: 0.223 - mean_q: 0.269 - mean_eps: 0.759 - lives: 2.034
#
# Interval 55 (540000 steps performed)
# 10000/10000 [==============================] - 78s 8ms/step - reward: 0.0172
# 15 episodes - episode_reward: 11.067 [5.000, 18.000] - loss: 0.007 - mae: 0.224 - mean_q: 0.270 - mean_eps: 0.755 - lives: 1.967
#
# Interval 56 (550000 steps performed)
# 10000/10000 [==============================] - 79s 8ms/step - reward: 0.0154
# 14 episodes - episode_reward: 10.929 [3.000, 25.000] - loss: 0.007 - mae: 0.218 - mean_q: 0.263 - mean_eps: 0.750 - lives: 2.084
#
# Interval 57 (560000 steps performed)
# 10000/10000 [==============================] - 78s 8ms/step - reward: 0.0145
# 14 episodes - episode_reward: 10.429 [4.000, 23.000] - loss: 0.007 - mae: 0.221 - mean_q: 0.268 - mean_eps: 0.746 - lives: 2.022
#
# Interval 58 (570000 steps performed)
# 10000/10000 [==============================] - 79s 8ms/step - reward: 0.0140
# 14 episodes - episode_reward: 9.786 [4.000, 19.000] - loss: 0.007 - mae: 0.223 - mean_q: 0.270 - mean_eps: 0.741 - lives: 1.976
#
# Interval 59 (580000 steps performed)
# 10000/10000 [==============================] - 81s 8ms/step - reward: 0.0161
# 15 episodes - episode_reward: 11.333 [5.000, 19.000] - loss: 0.007 - mae: 0.216 - mean_q: 0.262 - mean_eps: 0.737 - lives: 2.215
#
# Interval 60 (590000 steps performed)
# 10000/10000 [==============================] - 82s 8ms/step - reward: 0.0147
# 13 episodes - episode_reward: 11.308 [2.000, 18.000] - loss: 0.006 - mae: 0.212 - mean_q: 0.256 - mean_eps: 0.732 - lives: 2.027
#
# Interval 61 (600000 steps performed)
# 10000/10000 [==============================] - 81s 8ms/step - reward: 0.0135
# 16 episodes - episode_reward: 8.438 [0.000, 20.000] - loss: 0.007 - mae: 0.213 - mean_q: 0.258 - mean_eps: 0.728 - lives: 2.116
#
# Interval 62 (610000 steps performed)
# 10000/10000 [==============================] - 81s 8ms/step - reward: 0.0155
# 12 episodes - episode_reward: 11.833 [4.000, 22.000] - loss: 0.007 - mae: 0.208 - mean_q: 0.253 - mean_eps: 0.723 - lives: 2.095
#
# Interval 63 (620000 steps performed)
# 10000/10000 [==============================] - 83s 8ms/step - reward: 0.0153
# 11 episodes - episode_reward: 14.727 [7.000, 21.000] - loss: 0.006 - mae: 0.205 - mean_q: 0.248 - mean_eps: 0.719 - lives: 2.053
#
# Interval 64 (630000 steps performed)
# 10000/10000 [==============================] - 83s 8ms/step - reward: 0.0146
# 17 episodes - episode_reward: 8.647 [2.000, 19.000] - loss: 0.007 - mae: 0.215 - mean_q: 0.260 - mean_eps: 0.714 - lives: 1.956
#
# Interval 65 (640000 steps performed)
# 10000/10000 [==============================] - 84s 8ms/step - reward: 0.0152
# 16 episodes - episode_reward: 9.188 [4.000, 17.000] - loss: 0.007 - mae: 0.214 - mean_q: 0.258 - mean_eps: 0.710 - lives: 2.115
#
# Interval 66 (650000 steps performed)
# 10000/10000 [==============================] - 83s 8ms/step - reward: 0.0136
# 16 episodes - episode_reward: 8.688 [4.000, 18.000] - loss: 0.007 - mae: 0.210 - mean_q: 0.255 - mean_eps: 0.705 - lives: 2.087
#
# Interval 67 (660000 steps performed)
# 10000/10000 [==============================] - 84s 8ms/step - reward: 0.0161
# 14 episodes - episode_reward: 11.857 [6.000, 24.000] - loss: 0.007 - mae: 0.212 - mean_q: 0.256 - mean_eps: 0.701 - lives: 2.053
#
# Interval 68 (670000 steps performed)
# 10000/10000 [==============================] - 84s 8ms/step - reward: 0.0164
# 14 episodes - episode_reward: 10.786 [4.000, 23.000] - loss: 0.007 - mae: 0.218 - mean_q: 0.264 - mean_eps: 0.696 - lives: 2.035
#
# Interval 69 (680000 steps performed)
# 10000/10000 [==============================] - 84s 8ms/step - reward: 0.0144
# 15 episodes - episode_reward: 10.467 [2.000, 20.000] - loss: 0.007 - mae: 0.211 - mean_q: 0.255 - mean_eps: 0.692 - lives: 1.996
#
# Interval 70 (690000 steps performed)
# 10000/10000 [==============================] - 85s 9ms/step - reward: 0.0154
# 15 episodes - episode_reward: 9.667 [2.000, 18.000] - loss: 0.006 - mae: 0.207 - mean_q: 0.250 - mean_eps: 0.687 - lives: 1.985
#
# Interval 71 (700000 steps performed)
# 10000/10000 [==============================] - 85s 8ms/step - reward: 0.0131
# 14 episodes - episode_reward: 9.857 [3.000, 18.000] - loss: 0.007 - mae: 0.202 - mean_q: 0.244 - mean_eps: 0.683 - lives: 2.021
#
# Interval 72 (710000 steps performed)
# 10000/10000 [==============================] - 85s 9ms/step - reward: 0.0163
# 12 episodes - episode_reward: 11.667 [4.000, 20.000] - loss: 0.007 - mae: 0.201 - mean_q: 0.242 - mean_eps: 0.678 - lives: 2.019
#
# Interval 73 (720000 steps performed)
# 10000/10000 [==============================] - 85s 9ms/step - reward: 0.0169
# 16 episodes - episode_reward: 11.812 [4.000, 26.000] - loss: 0.007 - mae: 0.202 - mean_q: 0.243 - mean_eps: 0.674 - lives: 2.048
#
# Interval 74 (730000 steps performed)
# 10000/10000 [==============================] - 86s 9ms/step - reward: 0.0166
# 14 episodes - episode_reward: 11.929 [5.000, 24.000] - loss: 0.007 - mae: 0.207 - mean_q: 0.251 - mean_eps: 0.669 - lives: 1.996
#
# Interval 75 (740000 steps performed)
# 10000/10000 [==============================] - 87s 9ms/step - reward: 0.0163
# 17 episodes - episode_reward: 9.353 [0.000, 28.000] - loss: 0.007 - mae: 0.212 - mean_q: 0.255 - mean_eps: 0.665 - lives: 2.058
#
# Interval 76 (750000 steps performed)
# 10000/10000 [==============================] - 87s 9ms/step - reward: 0.0147
# 17 episodes - episode_reward: 9.118 [5.000, 14.000] - loss: 0.007 - mae: 0.209 - mean_q: 0.252 - mean_eps: 0.660 - lives: 2.060
#
# Interval 77 (760000 steps performed)
# 10000/10000 [==============================] - 87s 9ms/step - reward: 0.0157
# 15 episodes - episode_reward: 10.067 [6.000, 24.000] - loss: 0.006 - mae: 0.205 - mean_q: 0.248 - mean_eps: 0.656 - lives: 1.951
#
# Interval 78 (770000 steps performed)
# 10000/10000 [==============================] - 89s 9ms/step - reward: 0.0173
# 17 episodes - episode_reward: 10.235 [3.000, 22.000] - loss: 0.007 - mae: 0.203 - mean_q: 0.245 - mean_eps: 0.651 - lives: 1.966
#
# Interval 79 (780000 steps performed)
# 10000/10000 [==============================] - 88s 9ms/step - reward: 0.0145
# 14 episodes - episode_reward: 10.071 [5.000, 18.000] - loss: 0.007 - mae: 0.199 - mean_q: 0.240 - mean_eps: 0.647 - lives: 2.008
#
# Interval 80 (790000 steps performed)
# 10000/10000 [==============================] - 89s 9ms/step - reward: 0.0161
# 17 episodes - episode_reward: 9.647 [4.000, 18.000] - loss: 0.007 - mae: 0.209 - mean_q: 0.252 - mean_eps: 0.642 - lives: 2.062
#
# Interval 81 (800000 steps performed)
# 10000/10000 [==============================] - 89s 9ms/step - reward: 0.0168
# 15 episodes - episode_reward: 10.867 [1.000, 25.000] - loss: 0.006 - mae: 0.212 - mean_q: 0.257 - mean_eps: 0.638 - lives: 2.061
#
# Interval 82 (810000 steps performed)
# 10000/10000 [==============================] - 89s 9ms/step - reward: 0.0162
# 13 episodes - episode_reward: 12.077 [4.000, 30.000] - loss: 0.007 - mae: 0.214 - mean_q: 0.259 - mean_eps: 0.633 - lives: 1.887
#
# Interval 83 (820000 steps performed)
# 10000/10000 [==============================] - 90s 9ms/step - reward: 0.0157
# 16 episodes - episode_reward: 10.812 [4.000, 24.000] - loss: 0.006 - mae: 0.211 - mean_q: 0.256 - mean_eps: 0.629 - lives: 1.894
#
# Interval 84 (830000 steps performed)
# 10000/10000 [==============================] - 90s 9ms/step - reward: 0.0144
# 15 episodes - episode_reward: 9.533 [4.000, 24.000] - loss: 0.007 - mae: 0.215 - mean_q: 0.259 - mean_eps: 0.624 - lives: 2.082
#
# Interval 85 (840000 steps performed)
# 10000/10000 [==============================] - 89s 9ms/step - reward: 0.0152
# 17 episodes - episode_reward: 8.765 [2.000, 16.000] - loss: 0.006 - mae: 0.220 - mean_q: 0.265 - mean_eps: 0.620 - lives: 2.050
#
# Interval 86 (850000 steps performed)
# 10000/10000 [==============================] - 90s 9ms/step - reward: 0.0160
# 15 episodes - episode_reward: 10.733 [2.000, 19.000] - loss: 0.006 - mae: 0.212 - mean_q: 0.255 - mean_eps: 0.615 - lives: 2.200
#
# Interval 87 (860000 steps performed)
# 10000/10000 [==============================] - 90s 9ms/step - reward: 0.0144
# 17 episodes - episode_reward: 8.000 [3.000, 20.000] - loss: 0.006 - mae: 0.206 - mean_q: 0.249 - mean_eps: 0.611 - lives: 2.001
#
# Interval 88 (870000 steps performed)
# 10000/10000 [==============================] - 90s 9ms/step - reward: 0.0173
# 17 episodes - episode_reward: 10.824 [4.000, 27.000] - loss: 0.006 - mae: 0.206 - mean_q: 0.248 - mean_eps: 0.606 - lives: 2.036
#
# Interval 89 (880000 steps performed)
# 10000/10000 [==============================] - 91s 9ms/step - reward: 0.0161
# 15 episodes - episode_reward: 10.267 [5.000, 27.000] - loss: 0.007 - mae: 0.210 - mean_q: 0.253 - mean_eps: 0.602 - lives: 2.072
#
# Interval 90 (890000 steps performed)
# 10000/10000 [==============================] - 91s 9ms/step - reward: 0.0146
# 14 episodes - episode_reward: 10.214 [5.000, 23.000] - loss: 0.007 - mae: 0.217 - mean_q: 0.263 - mean_eps: 0.597 - lives: 1.950
#
# Interval 91 (900000 steps performed)
# 10000/10000 [==============================] - 91s 9ms/step - reward: 0.0187
# 12 episodes - episode_reward: 15.500 [9.000, 23.000] - loss: 0.007 - mae: 0.219 - mean_q: 0.264 - mean_eps: 0.593 - lives: 2.004
#
# Interval 92 (910000 steps performed)
# 10000/10000 [==============================] - 92s 9ms/step - reward: 0.0185
# 12 episodes - episode_reward: 16.000 [7.000, 27.000] - loss: 0.007 - mae: 0.218 - mean_q: 0.263 - mean_eps: 0.588 - lives: 2.129
#
# Interval 93 (920000 steps performed)
# 10000/10000 [==============================] - 92s 9ms/step - reward: 0.0149
# 14 episodes - episode_reward: 10.571 [3.000, 18.000] - loss: 0.007 - mae: 0.220 - mean_q: 0.266 - mean_eps: 0.584 - lives: 2.060
#
# Interval 94 (930000 steps performed)
# 10000/10000 [==============================] - 92s 9ms/step - reward: 0.0141
# 13 episodes - episode_reward: 10.846 [6.000, 19.000] - loss: 0.007 - mae: 0.223 - mean_q: 0.269 - mean_eps: 0.579 - lives: 2.082
#
# Interval 95 (940000 steps performed)
# 10000/10000 [==============================] - 93s 9ms/step - reward: 0.0158
# 15 episodes - episode_reward: 10.467 [4.000, 18.000] - loss: 0.007 - mae: 0.231 - mean_q: 0.281 - mean_eps: 0.575 - lives: 2.081
#
# Interval 96 (950000 steps performed)
# 10000/10000 [==============================] - 93s 9ms/step - reward: 0.0173
# 15 episodes - episode_reward: 11.933 [6.000, 30.000] - loss: 0.007 - mae: 0.231 - mean_q: 0.280 - mean_eps: 0.570 - lives: 1.960
#
# Interval 97 (960000 steps performed)
# 10000/10000 [==============================] - 93s 9ms/step - reward: 0.0147
# 15 episodes - episode_reward: 9.533 [1.000, 23.000] - loss: 0.007 - mae: 0.235 - mean_q: 0.283 - mean_eps: 0.566 - lives: 2.107
#
# Interval 98 (970000 steps performed)
# 10000/10000 [==============================] - 93s 9ms/step - reward: 0.0167
# 15 episodes - episode_reward: 11.133 [5.000, 19.000] - loss: 0.007 - mae: 0.236 - mean_q: 0.286 - mean_eps: 0.561 - lives: 2.066
#
# Interval 99 (980000 steps performed)
# 10000/10000 [==============================] - 94s 9ms/step - reward: 0.0178
# 14 episodes - episode_reward: 11.429 [0.000, 30.000] - loss: 0.007 - mae: 0.232 - mean_q: 0.280 - mean_eps: 0.557 - lives: 1.954
#
# Interval 100 (990000 steps performed)
# 10000/10000 [==============================] - 94s 9ms/step - reward: 0.0156
# 17 episodes - episode_reward: 9.647 [4.000, 23.000] - loss: 0.008 - mae: 0.235 - mean_q: 0.282 - mean_eps: 0.552 - lives: 2.148
#
# Interval 101 (1000000 steps performed)
# 10000/10000 [==============================] - 95s 9ms/step - reward: 0.0145
# 15 episodes - episode_reward: 10.533 [5.000, 18.000] - loss: 0.007 - mae: 0.241 - mean_q: 0.290 - mean_eps: 0.548 - lives: 2.031
#
# Interval 102 (1010000 steps performed)
# 10000/10000 [==============================] - 95s 9ms/step - reward: 0.0208
# 13 episodes - episode_reward: 14.923 [5.000, 35.000] - loss: 0.006 - mae: 0.246 - mean_q: 0.297 - mean_eps: 0.543 - lives: 2.190
#
# Interval 103 (1020000 steps performed)
# 10000/10000 [==============================] - 95s 9ms/step - reward: 0.0179
# 13 episodes - episode_reward: 14.077 [7.000, 25.000] - loss: 0.007 - mae: 0.236 - mean_q: 0.283 - mean_eps: 0.539 - lives: 2.021
#
# Interval 104 (1030000 steps performed)
# 10000/10000 [==============================] - 94s 9ms/step - reward: 0.0192
# 14 episodes - episode_reward: 14.071 [5.000, 26.000] - loss: 0.006 - mae: 0.228 - mean_q: 0.274 - mean_eps: 0.534 - lives: 2.081
#
# Interval 105 (1040000 steps performed)
# 10000/10000 [==============================] - 95s 9ms/step - reward: 0.0144
# 14 episodes - episode_reward: 9.500 [3.000, 15.000] - loss: 0.007 - mae: 0.231 - mean_q: 0.279 - mean_eps: 0.530 - lives: 2.152
#
# Interval 106 (1050000 steps performed)
# 10000/10000 [==============================] - 95s 9ms/step - reward: 0.0169
# 17 episodes - episode_reward: 10.941 [3.000, 21.000] - loss: 0.008 - mae: 0.222 - mean_q: 0.268 - mean_eps: 0.525 - lives: 2.199
#
# Interval 107 (1060000 steps performed)
# 10000/10000 [==============================] - 94s 9ms/step - reward: 0.0184
# 14 episodes - episode_reward: 13.143 [6.000, 25.000] - loss: 0.006 - mae: 0.216 - mean_q: 0.262 - mean_eps: 0.521 - lives: 2.073
#
# Interval 108 (1070000 steps performed)
# 10000/10000 [==============================] - 94s 9ms/step - reward: 0.0165
# 14 episodes - episode_reward: 11.214 [2.000, 22.000] - loss: 0.007 - mae: 0.224 - mean_q: 0.270 - mean_eps: 0.516 - lives: 2.016
#
# Interval 109 (1080000 steps performed)
# 10000/10000 [==============================] - 93s 9ms/step - reward: 0.0165
# 14 episodes - episode_reward: 12.000 [6.000, 27.000] - loss: 0.007 - mae: 0.222 - mean_q: 0.267 - mean_eps: 0.512 - lives: 2.021
#
# Interval 110 (1090000 steps performed)
# 10000/10000 [==============================] - 94s 9ms/step - reward: 0.0155
# 12 episodes - episode_reward: 12.500 [5.000, 29.000] - loss: 0.007 - mae: 0.218 - mean_q: 0.262 - mean_eps: 0.507 - lives: 1.863
#
# Interval 111 (1100000 steps performed)
# 10000/10000 [==============================] - 93s 9ms/step - reward: 0.0144
# 14 episodes - episode_reward: 10.857 [3.000, 27.000] - loss: 0.007 - mae: 0.212 - mean_q: 0.255 - mean_eps: 0.503 - lives: 2.053
#
# Interval 112 (1110000 steps performed)
# 10000/10000 [==============================] - 93s 9ms/step - reward: 0.0213
# 15 episodes - episode_reward: 14.133 [5.000, 23.000] - loss: 0.007 - mae: 0.215 - mean_q: 0.261 - mean_eps: 0.498 - lives: 2.030
#
# Interval 113 (1120000 steps performed)
# 10000/10000 [==============================] - 93s 9ms/step - reward: 0.0148
# 15 episodes - episode_reward: 9.933 [5.000, 17.000] - loss: 0.007 - mae: 0.225 - mean_q: 0.271 - mean_eps: 0.494 - lives: 2.035
#
# Interval 114 (1130000 steps performed)
# 10000/10000 [==============================] - 94s 9ms/step - reward: 0.0156
# 15 episodes - episode_reward: 10.333 [5.000, 21.000] - loss: 0.007 - mae: 0.230 - mean_q: 0.277 - mean_eps: 0.489 - lives: 1.958
#
# Interval 115 (1140000 steps performed)
# 10000/10000 [==============================] - 94s 9ms/step - reward: 0.0180
# 15 episodes - episode_reward: 12.200 [3.000, 23.000] - loss: 0.007 - mae: 0.233 - mean_q: 0.282 - mean_eps: 0.485 - lives: 2.042
#
# Interval 116 (1150000 steps performed)
# 10000/10000 [==============================] - 94s 9ms/step - reward: 0.0151
# 15 episodes - episode_reward: 9.733 [4.000, 20.000] - loss: 0.007 - mae: 0.225 - mean_q: 0.272 - mean_eps: 0.480 - lives: 2.009
#
# Interval 117 (1160000 steps performed)
# 10000/10000 [==============================] - 94s 9ms/step - reward: 0.0166
# 14 episodes - episode_reward: 12.143 [4.000, 19.000] - loss: 0.007 - mae: 0.232 - mean_q: 0.280 - mean_eps: 0.476 - lives: 2.073
#
# Interval 118 (1170000 steps performed)
# 10000/10000 [==============================] - 95s 9ms/step - reward: 0.0195
# 15 episodes - episode_reward: 12.733 [5.000, 23.000] - loss: 0.007 - mae: 0.234 - mean_q: 0.285 - mean_eps: 0.471 - lives: 2.034
#
# Interval 119 (1180000 steps performed)
# 10000/10000 [==============================] - 94s 9ms/step - reward: 0.0159
# 14 episodes - episode_reward: 11.429 [4.000, 21.000] - loss: 0.007 - mae: 0.221 - mean_q: 0.268 - mean_eps: 0.467 - lives: 1.989
#
# Interval 120 (1190000 steps performed)
# 10000/10000 [==============================] - 95s 9ms/step - reward: 0.0161
# 12 episodes - episode_reward: 13.583 [6.000, 21.000] - loss: 0.007 - mae: 0.215 - mean_q: 0.261 - mean_eps: 0.462 - lives: 2.021
#
# Interval 121 (1200000 steps performed)
# 10000/10000 [==============================] - 95s 9ms/step - reward: 0.0164
# 13 episodes - episode_reward: 11.846 [4.000, 21.000] - loss: 0.007 - mae: 0.209 - mean_q: 0.251 - mean_eps: 0.458 - lives: 2.056
#
# Interval 122 (1210000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0170
# 14 episodes - episode_reward: 12.429 [5.000, 24.000] - loss: 0.007 - mae: 0.212 - mean_q: 0.256 - mean_eps: 0.453 - lives: 2.158
#
# Interval 123 (1220000 steps performed)
# 10000/10000 [==============================] - 95s 10ms/step - reward: 0.0158
# 14 episodes - episode_reward: 10.857 [4.000, 22.000] - loss: 0.007 - mae: 0.210 - mean_q: 0.253 - mean_eps: 0.449 - lives: 2.166
#
# Interval 124 (1230000 steps performed)
# 10000/10000 [==============================] - 95s 9ms/step - reward: 0.0152
# 17 episodes - episode_reward: 9.412 [4.000, 23.000] - loss: 0.007 - mae: 0.212 - mean_q: 0.256 - mean_eps: 0.444 - lives: 2.206
#
# Interval 125 (1240000 steps performed)
# 10000/10000 [==============================] - 95s 10ms/step - reward: 0.0153
# 15 episodes - episode_reward: 10.133 [6.000, 23.000] - loss: 0.007 - mae: 0.222 - mean_q: 0.267 - mean_eps: 0.440 - lives: 2.122
#
# Interval 126 (1250000 steps performed)
# 10000/10000 [==============================] - 95s 9ms/step - reward: 0.0169
# 15 episodes - episode_reward: 11.200 [2.000, 22.000] - loss: 0.007 - mae: 0.216 - mean_q: 0.262 - mean_eps: 0.435 - lives: 2.030
#
# Interval 127 (1260000 steps performed)
# 10000/10000 [==============================] - 95s 10ms/step - reward: 0.0154
# 14 episodes - episode_reward: 11.571 [5.000, 22.000] - loss: 0.008 - mae: 0.214 - mean_q: 0.257 - mean_eps: 0.431 - lives: 2.036
#
# Interval 128 (1270000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0166
# 15 episodes - episode_reward: 11.067 [3.000, 17.000] - loss: 0.007 - mae: 0.199 - mean_q: 0.241 - mean_eps: 0.426 - lives: 2.227
#
# Interval 129 (1280000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0192
# 15 episodes - episode_reward: 11.800 [3.000, 20.000] - loss: 0.007 - mae: 0.198 - mean_q: 0.238 - mean_eps: 0.422 - lives: 2.083
#
# Interval 130 (1290000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0150
# 14 episodes - episode_reward: 11.714 [2.000, 26.000] - loss: 0.008 - mae: 0.200 - mean_q: 0.240 - mean_eps: 0.417 - lives: 1.907
#
# Interval 131 (1300000 steps performed)
# 10000/10000 [==============================] - 95s 10ms/step - reward: 0.0192
# 13 episodes - episode_reward: 14.077 [4.000, 25.000] - loss: 0.006 - mae: 0.207 - mean_q: 0.248 - mean_eps: 0.413 - lives: 2.167
#
# Interval 132 (1310000 steps performed)
# 10000/10000 [==============================] - 95s 9ms/step - reward: 0.0163
# 14 episodes - episode_reward: 12.286 [6.000, 34.000] - loss: 0.007 - mae: 0.203 - mean_q: 0.243 - mean_eps: 0.408 - lives: 2.060
#
# Interval 133 (1320000 steps performed)
# 10000/10000 [==============================] - 94s 9ms/step - reward: 0.0187
# 13 episodes - episode_reward: 13.846 [6.000, 27.000] - loss: 0.007 - mae: 0.199 - mean_q: 0.239 - mean_eps: 0.404 - lives: 2.055
#
# Interval 134 (1330000 steps performed)
# 10000/10000 [==============================] - 95s 10ms/step - reward: 0.0167
# 17 episodes - episode_reward: 9.529 [2.000, 22.000] - loss: 0.008 - mae: 0.205 - mean_q: 0.245 - mean_eps: 0.399 - lives: 2.075
#
# Interval 135 (1340000 steps performed)
# 10000/10000 [==============================] - 95s 9ms/step - reward: 0.0175
# 15 episodes - episode_reward: 12.533 [5.000, 23.000] - loss: 0.008 - mae: 0.211 - mean_q: 0.254 - mean_eps: 0.395 - lives: 2.139
#
# Interval 136 (1350000 steps performed)
# 10000/10000 [==============================] - 95s 9ms/step - reward: 0.0156
# 14 episodes - episode_reward: 11.143 [5.000, 20.000] - loss: 0.008 - mae: 0.209 - mean_q: 0.252 - mean_eps: 0.390 - lives: 2.130
#
# Interval 137 (1360000 steps performed)
# 10000/10000 [==============================] - 95s 9ms/step - reward: 0.0167
# 15 episodes - episode_reward: 10.533 [3.000, 30.000] - loss: 0.007 - mae: 0.205 - mean_q: 0.247 - mean_eps: 0.386 - lives: 2.104
#
# Interval 138 (1370000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0159
# 15 episodes - episode_reward: 10.800 [2.000, 26.000] - loss: 0.007 - mae: 0.212 - mean_q: 0.255 - mean_eps: 0.381 - lives: 2.121
#
# Interval 139 (1380000 steps performed)
# 10000/10000 [==============================] - 95s 10ms/step - reward: 0.0171
# 16 episodes - episode_reward: 10.375 [3.000, 26.000] - loss: 0.007 - mae: 0.217 - mean_q: 0.261 - mean_eps: 0.377 - lives: 2.179
#
# Interval 140 (1390000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0161
# 15 episodes - episode_reward: 11.000 [7.000, 18.000] - loss: 0.007 - mae: 0.211 - mean_q: 0.254 - mean_eps: 0.372 - lives: 2.158
#
# Interval 141 (1400000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0168
# 13 episodes - episode_reward: 13.000 [7.000, 21.000] - loss: 0.007 - mae: 0.214 - mean_q: 0.258 - mean_eps: 0.368 - lives: 1.975
#
# Interval 142 (1410000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0155
# 14 episodes - episode_reward: 11.143 [4.000, 21.000] - loss: 0.007 - mae: 0.220 - mean_q: 0.266 - mean_eps: 0.363 - lives: 2.204
#
# Interval 143 (1420000 steps performed)
# 10000/10000 [==============================] - 95s 10ms/step - reward: 0.0141
# 13 episodes - episode_reward: 10.923 [5.000, 20.000] - loss: 0.007 - mae: 0.214 - mean_q: 0.260 - mean_eps: 0.359 - lives: 1.992
#
# Interval 144 (1430000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0179
# 16 episodes - episode_reward: 10.750 [4.000, 24.000] - loss: 0.008 - mae: 0.229 - mean_q: 0.277 - mean_eps: 0.354 - lives: 2.086
#
# Interval 145 (1440000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0166
# 15 episodes - episode_reward: 11.067 [8.000, 22.000] - loss: 0.008 - mae: 0.238 - mean_q: 0.286 - mean_eps: 0.350 - lives: 2.093
#
# Interval 146 (1450000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0145
# 13 episodes - episode_reward: 11.846 [5.000, 27.000] - loss: 0.008 - mae: 0.228 - mean_q: 0.275 - mean_eps: 0.345 - lives: 2.142
#
# Interval 147 (1460000 steps performed)
# 10000/10000 [==============================] - 95s 10ms/step - reward: 0.0194
# 13 episodes - episode_reward: 13.846 [5.000, 28.000] - loss: 0.008 - mae: 0.233 - mean_q: 0.280 - mean_eps: 0.341 - lives: 2.118
#
# Interval 148 (1470000 steps performed)
# 10000/10000 [==============================] - 95s 10ms/step - reward: 0.0193
# 16 episodes - episode_reward: 11.688 [5.000, 20.000] - loss: 0.007 - mae: 0.231 - mean_q: 0.278 - mean_eps: 0.336 - lives: 2.076
#
# Interval 149 (1480000 steps performed)
# 10000/10000 [==============================] - 95s 10ms/step - reward: 0.0140
# 13 episodes - episode_reward: 11.538 [5.000, 27.000] - loss: 0.007 - mae: 0.243 - mean_q: 0.291 - mean_eps: 0.332 - lives: 2.085
#
# Interval 150 (1490000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0165
# 16 episodes - episode_reward: 10.750 [2.000, 26.000] - loss: 0.008 - mae: 0.231 - mean_q: 0.277 - mean_eps: 0.327 - lives: 2.228
#
# Interval 151 (1500000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0170
# 15 episodes - episode_reward: 11.667 [4.000, 23.000] - loss: 0.007 - mae: 0.231 - mean_q: 0.278 - mean_eps: 0.323 - lives: 2.086
#
# Interval 152 (1510000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0190
# 12 episodes - episode_reward: 15.167 [6.000, 29.000] - loss: 0.007 - mae: 0.236 - mean_q: 0.283 - mean_eps: 0.318 - lives: 2.077
#
# Interval 153 (1520000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0179
# 14 episodes - episode_reward: 12.286 [7.000, 20.000] - loss: 0.007 - mae: 0.235 - mean_q: 0.282 - mean_eps: 0.314 - lives: 1.887
#
# Interval 154 (1530000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0188
# 12 episodes - episode_reward: 15.417 [7.000, 30.000] - loss: 0.008 - mae: 0.228 - mean_q: 0.273 - mean_eps: 0.309 - lives: 1.970
#
# Interval 155 (1540000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0167
# 12 episodes - episode_reward: 14.417 [6.000, 30.000] - loss: 0.007 - mae: 0.223 - mean_q: 0.269 - mean_eps: 0.305 - lives: 2.206
#
# Interval 156 (1550000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0153
# 12 episodes - episode_reward: 11.750 [8.000, 18.000] - loss: 0.007 - mae: 0.231 - mean_q: 0.277 - mean_eps: 0.300 - lives: 1.965
#
# Interval 157 (1560000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0189
# 13 episodes - episode_reward: 15.923 [6.000, 34.000] - loss: 0.007 - mae: 0.231 - mean_q: 0.279 - mean_eps: 0.296 - lives: 2.190
#
# Interval 158 (1570000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0172
# 15 episodes - episode_reward: 11.400 [4.000, 20.000] - loss: 0.007 - mae: 0.222 - mean_q: 0.266 - mean_eps: 0.291 - lives: 2.101
#
# Interval 159 (1580000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0197
# 13 episodes - episode_reward: 15.000 [7.000, 24.000] - loss: 0.007 - mae: 0.220 - mean_q: 0.264 - mean_eps: 0.287 - lives: 2.106
#
# Interval 160 (1590000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0158
# 13 episodes - episode_reward: 12.077 [4.000, 18.000] - loss: 0.007 - mae: 0.215 - mean_q: 0.258 - mean_eps: 0.282 - lives: 2.087
#
# Interval 161 (1600000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0177
# 15 episodes - episode_reward: 12.333 [3.000, 23.000] - loss: 0.007 - mae: 0.222 - mean_q: 0.267 - mean_eps: 0.278 - lives: 2.058
#
# Interval 162 (1610000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: 0.0159
# 13 episodes - episode_reward: 12.000 [5.000, 25.000] - loss: 0.008 - mae: 0.222 - mean_q: 0.269 - mean_eps: 0.273 - lives: 2.075
#
# Interval 163 (1620000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0170
# 13 episodes - episode_reward: 11.769 [7.000, 24.000] - loss: 0.007 - mae: 0.217 - mean_q: 0.264 - mean_eps: 0.269 - lives: 2.022
#
# Interval 164 (1630000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0186
# 13 episodes - episode_reward: 15.308 [6.000, 28.000] - loss: 0.007 - mae: 0.208 - mean_q: 0.251 - mean_eps: 0.264 - lives: 2.052
#
# Interval 165 (1640000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0170
# 13 episodes - episode_reward: 12.846 [7.000, 19.000] - loss: 0.007 - mae: 0.206 - mean_q: 0.247 - mean_eps: 0.260 - lives: 2.105
#
# Interval 166 (1650000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0173
# 12 episodes - episode_reward: 14.833 [10.000, 24.000] - loss: 0.007 - mae: 0.204 - mean_q: 0.245 - mean_eps: 0.255 - lives: 1.995
#
# Interval 167 (1660000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0155
# 12 episodes - episode_reward: 12.167 [7.000, 21.000] - loss: 0.007 - mae: 0.204 - mean_q: 0.245 - mean_eps: 0.251 - lives: 1.966
#
# Interval 168 (1670000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0169
# 15 episodes - episode_reward: 12.333 [7.000, 25.000] - loss: 0.007 - mae: 0.203 - mean_q: 0.245 - mean_eps: 0.246 - lives: 1.995
#
# Interval 169 (1680000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0161
# 14 episodes - episode_reward: 10.857 [6.000, 18.000] - loss: 0.008 - mae: 0.203 - mean_q: 0.244 - mean_eps: 0.242 - lives: 2.167
#
# Interval 170 (1690000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0177
# 16 episodes - episode_reward: 11.000 [3.000, 22.000] - loss: 0.007 - mae: 0.221 - mean_q: 0.267 - mean_eps: 0.237 - lives: 2.180
#
# Interval 171 (1700000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0170
# 14 episodes - episode_reward: 12.786 [7.000, 29.000] - loss: 0.007 - mae: 0.213 - mean_q: 0.256 - mean_eps: 0.233 - lives: 2.014
#
# Interval 172 (1710000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0182
# 15 episodes - episode_reward: 11.733 [5.000, 24.000] - loss: 0.007 - mae: 0.207 - mean_q: 0.249 - mean_eps: 0.228 - lives: 2.027
#
# Interval 173 (1720000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0180
# 16 episodes - episode_reward: 11.625 [6.000, 20.000] - loss: 0.007 - mae: 0.205 - mean_q: 0.246 - mean_eps: 0.224 - lives: 2.050
#
# Interval 174 (1730000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0185
# 12 episodes - episode_reward: 14.833 [4.000, 31.000] - loss: 0.008 - mae: 0.221 - mean_q: 0.265 - mean_eps: 0.219 - lives: 2.003
#
# Interval 175 (1740000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0166
# 12 episodes - episode_reward: 14.500 [7.000, 28.000] - loss: 0.007 - mae: 0.214 - mean_q: 0.259 - mean_eps: 0.215 - lives: 2.010
#
# Interval 176 (1750000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0151
# 11 episodes - episode_reward: 13.727 [8.000, 29.000] - loss: 0.007 - mae: 0.216 - mean_q: 0.260 - mean_eps: 0.210 - lives: 1.996
#
# Interval 177 (1760000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0205
# 12 episodes - episode_reward: 16.583 [7.000, 30.000] - loss: 0.008 - mae: 0.217 - mean_q: 0.261 - mean_eps: 0.206 - lives: 1.984
#
# Interval 178 (1770000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0188
# 15 episodes - episode_reward: 12.133 [5.000, 20.000] - loss: 0.007 - mae: 0.205 - mean_q: 0.247 - mean_eps: 0.201 - lives: 2.253
#
# Interval 179 (1780000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0192
# 14 episodes - episode_reward: 13.929 [7.000, 20.000] - loss: 0.007 - mae: 0.206 - mean_q: 0.248 - mean_eps: 0.197 - lives: 2.091
#
# Interval 180 (1790000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0187
# 14 episodes - episode_reward: 13.286 [6.000, 22.000] - loss: 0.008 - mae: 0.213 - mean_q: 0.256 - mean_eps: 0.192 - lives: 1.952
#
# Interval 181 (1800000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0191
# 15 episodes - episode_reward: 12.667 [6.000, 19.000] - loss: 0.008 - mae: 0.217 - mean_q: 0.260 - mean_eps: 0.188 - lives: 2.065
#
# Interval 182 (1810000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0192
# 15 episodes - episode_reward: 13.533 [4.000, 26.000] - loss: 0.007 - mae: 0.214 - mean_q: 0.257 - mean_eps: 0.183 - lives: 2.029
#
# Interval 183 (1820000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0149
# 12 episodes - episode_reward: 11.917 [5.000, 18.000] - loss: 0.007 - mae: 0.224 - mean_q: 0.269 - mean_eps: 0.179 - lives: 2.194
#
# Interval 184 (1830000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0169
# 14 episodes - episode_reward: 11.714 [6.000, 19.000] - loss: 0.007 - mae: 0.225 - mean_q: 0.271 - mean_eps: 0.174 - lives: 2.169
#
# Interval 185 (1840000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0179
# 15 episodes - episode_reward: 12.333 [7.000, 30.000] - loss: 0.007 - mae: 0.236 - mean_q: 0.285 - mean_eps: 0.170 - lives: 1.959
#
# Interval 186 (1850000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0147
# 14 episodes - episode_reward: 9.500 [1.000, 17.000] - loss: 0.008 - mae: 0.247 - mean_q: 0.297 - mean_eps: 0.165 - lives: 2.099
#
# Interval 187 (1860000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0148
# 12 episodes - episode_reward: 12.917 [6.000, 35.000] - loss: 0.007 - mae: 0.230 - mean_q: 0.275 - mean_eps: 0.161 - lives: 2.003
#
# Interval 188 (1870000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0147
# 14 episodes - episode_reward: 11.071 [5.000, 20.000] - loss: 0.007 - mae: 0.230 - mean_q: 0.276 - mean_eps: 0.156 - lives: 2.072
#
# Interval 189 (1880000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0176
# 12 episodes - episode_reward: 14.917 [6.000, 33.000] - loss: 0.008 - mae: 0.243 - mean_q: 0.292 - mean_eps: 0.152 - lives: 2.016
#
# Interval 190 (1890000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0179
# 13 episodes - episode_reward: 12.615 [7.000, 24.000] - loss: 0.007 - mae: 0.232 - mean_q: 0.280 - mean_eps: 0.147 - lives: 2.064
#
# Interval 191 (1900000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0184
# 12 episodes - episode_reward: 15.750 [7.000, 26.000] - loss: 0.007 - mae: 0.223 - mean_q: 0.268 - mean_eps: 0.143 - lives: 2.033
#
# Interval 192 (1910000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0166
# 15 episodes - episode_reward: 11.467 [7.000, 19.000] - loss: 0.008 - mae: 0.222 - mean_q: 0.267 - mean_eps: 0.138 - lives: 2.124
#
# Interval 193 (1920000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: 0.0154
# 15 episodes - episode_reward: 9.867 [6.000, 16.000] - loss: 0.007 - mae: 0.227 - mean_q: 0.274 - mean_eps: 0.134 - lives: 2.121
#
# Interval 194 (1930000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0165
# 18 episodes - episode_reward: 8.944 [5.000, 17.000] - loss: 0.007 - mae: 0.227 - mean_q: 0.274 - mean_eps: 0.129 - lives: 2.123
#
# Interval 195 (1940000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: 0.0179
# ...
#
# Interval 236 (2350000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0176
# 15 episodes - episode_reward: 11.533 [6.000, 24.000] - loss: 0.007 - mae: 0.235 - mean_q: 0.283 - mean_eps: 0.100 - lives: 1.984
#
# Interval 237 (2360000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0205
# 18 episodes - episode_reward: 10.944 [6.000, 17.000] - loss: 0.007 - mae: 0.227 - mean_q: 0.273 - mean_eps: 0.100 - lives: 2.039
#
# Interval 238 (2370000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0207
# 15 episodes - episode_reward: 14.467 [7.000, 28.000] - loss: 0.008 - mae: 0.228 - mean_q: 0.275 - mean_eps: 0.100 - lives: 2.113
#
# Interval 239 (2380000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0203
# 14 episodes - episode_reward: 13.714 [7.000, 22.000] - loss: 0.007 - mae: 0.221 - mean_q: 0.267 - mean_eps: 0.100 - lives: 1.932
#
# Interval 240 (2390000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0172
# 12 episodes - episode_reward: 15.083 [7.000, 29.000] - loss: 0.007 - mae: 0.216 - mean_q: 0.261 - mean_eps: 0.100 - lives: 1.802
#
# Interval 241 (2400000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0183
# 18 episodes - episode_reward: 10.611 [4.000, 22.000] - loss: 0.007 - mae: 0.214 - mean_q: 0.258 - mean_eps: 0.100 - lives: 2.119
#
# Interval 242 (2410000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0217
# 17 episodes - episode_reward: 12.647 [4.000, 30.000] - loss: 0.007 - mae: 0.216 - mean_q: 0.261 - mean_eps: 0.100 - lives: 1.964
#
# Interval 243 (2420000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0216
# 14 episodes - episode_reward: 14.929 [7.000, 31.000] - loss: 0.007 - mae: 0.217 - mean_q: 0.262 - mean_eps: 0.100 - lives: 2.165
#
# Interval 244 (2430000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0165
# 16 episodes - episode_reward: 10.875 [6.000, 24.000] - loss: 0.007 - mae: 0.217 - mean_q: 0.262 - mean_eps: 0.100 - lives: 2.007
#
# Interval 245 (2440000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0186
# 14 episodes - episode_reward: 11.857 [4.000, 28.000] - loss: 0.008 - mae: 0.217 - mean_q: 0.262 - mean_eps: 0.100 - lives: 2.013
#
# Interval 246 (2450000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0195
# 14 episodes - episode_reward: 15.000 [7.000, 31.000] - loss: 0.007 - mae: 0.220 - mean_q: 0.266 - mean_eps: 0.100 - lives: 2.156
#
# Interval 247 (2460000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0183
# 14 episodes - episode_reward: 13.000 [6.000, 20.000] - loss: 0.008 - mae: 0.233 - mean_q: 0.281 - mean_eps: 0.100 - lives: 2.022
#
# Interval 248 (2470000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0179
# 16 episodes - episode_reward: 11.562 [4.000, 23.000] - loss: 0.007 - mae: 0.221 - mean_q: 0.268 - mean_eps: 0.100 - lives: 1.871
#
# Interval 249 (2480000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0185
# 19 episodes - episode_reward: 9.421 [4.000, 19.000] - loss: 0.008 - mae: 0.232 - mean_q: 0.279 - mean_eps: 0.100 - lives: 2.012
#
# Interval 250 (2490000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0195
# 13 episodes - episode_reward: 14.154 [6.000, 26.000] - loss: 0.007 - mae: 0.236 - mean_q: 0.286 - mean_eps: 0.100 - lives: 1.929
#
# Interval 251 (2500000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0178
# 16 episodes - episode_reward: 11.438 [2.000, 22.000] - loss: 0.007 - mae: 0.226 - mean_q: 0.274 - mean_eps: 0.100 - lives: 1.771
#
# Interval 252 (2510000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0179
# 18 episodes - episode_reward: 10.556 [2.000, 18.000] - loss: 0.007 - mae: 0.225 - mean_q: 0.270 - mean_eps: 0.100 - lives: 2.012
#
# Interval 253 (2520000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0193
# 17 episodes - episode_reward: 10.647 [3.000, 25.000] - loss: 0.007 - mae: 0.217 - mean_q: 0.262 - mean_eps: 0.100 - lives: 2.053
#
# Interval 254 (2530000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0199
# 14 episodes - episode_reward: 14.286 [3.000, 24.000] - loss: 0.008 - mae: 0.219 - mean_q: 0.266 - mean_eps: 0.100 - lives: 2.114
#
# Interval 255 (2540000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0221
# 11 episodes - episode_reward: 19.455 [8.000, 29.000] - loss: 0.008 - mae: 0.217 - mean_q: 0.262 - mean_eps: 0.100 - lives: 1.827
#
# Interval 256 (2550000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0202
# 12 episodes - episode_reward: 16.917 [8.000, 24.000] - loss: 0.008 - mae: 0.217 - mean_q: 0.262 - mean_eps: 0.100 - lives: 2.075
#
# Interval 257 (2560000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0221
# 16 episodes - episode_reward: 14.750 [6.000, 29.000] - loss: 0.007 - mae: 0.217 - mean_q: 0.262 - mean_eps: 0.100 - lives: 1.955
#
# Interval 258 (2570000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0219
# 13 episodes - episode_reward: 16.154 [7.000, 24.000] - loss: 0.008 - mae: 0.227 - mean_q: 0.273 - mean_eps: 0.100 - lives: 1.745
#
# Interval 259 (2580000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0191
# 14 episodes - episode_reward: 14.000 [7.000, 22.000] - loss: 0.008 - mae: 0.237 - mean_q: 0.285 - mean_eps: 0.100 - lives: 1.810
#
# Interval 260 (2590000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0190
# 12 episodes - episode_reward: 16.083 [8.000, 30.000] - loss: 0.008 - mae: 0.242 - mean_q: 0.293 - mean_eps: 0.100 - lives: 1.956
#
# Interval 261 (2600000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0151
# 14 episodes - episode_reward: 11.000 [4.000, 32.000] - loss: 0.008 - mae: 0.254 - mean_q: 0.306 - mean_eps: 0.100 - lives: 2.048
#
# Interval 262 (2610000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0221
# 14 episodes - episode_reward: 15.786 [8.000, 32.000] - loss: 0.008 - mae: 0.250 - mean_q: 0.301 - mean_eps: 0.100 - lives: 2.056
#
# Interval 263 (2620000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0220
# 15 episodes - episode_reward: 14.533 [6.000, 22.000] - loss: 0.007 - mae: 0.247 - mean_q: 0.299 - mean_eps: 0.100 - lives: 1.925
#
# Interval 264 (2630000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0229
# 12 episodes - episode_reward: 19.333 [7.000, 32.000] - loss: 0.008 - mae: 0.245 - mean_q: 0.297 - mean_eps: 0.100 - lives: 2.137
#
# Interval 265 (2640000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0198
# 12 episodes - episode_reward: 14.750 [5.000, 23.000] - loss: 0.007 - mae: 0.240 - mean_q: 0.292 - mean_eps: 0.100 - lives: 2.039
#
# Interval 266 (2650000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0213
# 16 episodes - episode_reward: 14.188 [4.000, 27.000] - loss: 0.008 - mae: 0.245 - mean_q: 0.297 - mean_eps: 0.100 - lives: 2.125
#
# Interval 267 (2660000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0193
# 13 episodes - episode_reward: 14.231 [7.000, 23.000] - loss: 0.008 - mae: 0.250 - mean_q: 0.303 - mean_eps: 0.100 - lives: 2.043
#
# Interval 268 (2670000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0189
# 12 episodes - episode_reward: 15.667 [6.000, 25.000] - loss: 0.008 - mae: 0.249 - mean_q: 0.301 - mean_eps: 0.100 - lives: 2.075
#
# Interval 269 (2680000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0222
# 12 episodes - episode_reward: 19.667 [7.000, 34.000] - loss: 0.008 - mae: 0.252 - mean_q: 0.303 - mean_eps: 0.100 - lives: 1.956
#
# Interval 270 (2690000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0219
# 17 episodes - episode_reward: 12.941 [7.000, 23.000] - loss: 0.008 - mae: 0.241 - mean_q: 0.292 - mean_eps: 0.100 - lives: 1.991
#
# Interval 271 (2700000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0160
# 16 episodes - episode_reward: 10.062 [6.000, 16.000] - loss: 0.007 - mae: 0.245 - mean_q: 0.296 - mean_eps: 0.100 - lives: 2.039
#
# Interval 272 (2710000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0214
# 12 episodes - episode_reward: 17.750 [6.000, 34.000] - loss: 0.008 - mae: 0.245 - mean_q: 0.296 - mean_eps: 0.100 - lives: 2.102
#
# Interval 273 (2720000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0197
# 14 episodes - episode_reward: 13.000 [8.000, 26.000] - loss: 0.007 - mae: 0.239 - mean_q: 0.289 - mean_eps: 0.100 - lives: 2.168
#
# Interval 274 (2730000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0198
# 14 episodes - episode_reward: 14.857 [5.000, 23.000] - loss: 0.008 - mae: 0.243 - mean_q: 0.293 - mean_eps: 0.100 - lives: 1.979
#
# Interval 275 (2740000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0163
# 16 episodes - episode_reward: 10.500 [6.000, 21.000] - loss: 0.007 - mae: 0.237 - mean_q: 0.286 - mean_eps: 0.100 - lives: 2.069
#
# Interval 276 (2750000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0223
# 16 episodes - episode_reward: 13.375 [6.000, 28.000] - loss: 0.008 - mae: 0.232 - mean_q: 0.279 - mean_eps: 0.100 - lives: 1.951
#
# Interval 277 (2760000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0184
# 13 episodes - episode_reward: 13.692 [5.000, 19.000] - loss: 0.007 - mae: 0.234 - mean_q: 0.282 - mean_eps: 0.100 - lives: 1.979
#
# Interval 278 (2770000 steps performed)
# 10000/10000 [==============================] - 101s 10ms/step - reward: 0.0207
# 16 episodes - episode_reward: 13.812 [4.000, 28.000] - loss: 0.008 - mae: 0.239 - mean_q: 0.288 - mean_eps: 0.100 - lives: 2.047
#
# Interval 279 (2780000 steps performed)
# 10000/10000 [==============================] - 101s 10ms/step - reward: 0.0210
# 16 episodes - episode_reward: 12.500 [3.000, 25.000] - loss: 0.007 - mae: 0.233 - mean_q: 0.282 - mean_eps: 0.100 - lives: 2.017
#
# Interval 280 (2790000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0254
# 14 episodes - episode_reward: 18.071 [5.000, 28.000] - loss: 0.008 - mae: 0.235 - mean_q: 0.284 - mean_eps: 0.100 - lives: 1.989
#
# Interval 281 (2800000 steps performed)
# 10000/10000 [==============================] - 101s 10ms/step - reward: 0.0209
# 15 episodes - episode_reward: 14.533 [6.000, 24.000] - loss: 0.007 - mae: 0.243 - mean_q: 0.295 - mean_eps: 0.100 - lives: 2.047
#
# Interval 282 (2810000 steps performed)
# 10000/10000 [==============================] - 101s 10ms/step - reward: 0.0202
# 16 episodes - episode_reward: 12.375 [4.000, 25.000] - loss: 0.007 - mae: 0.247 - mean_q: 0.300 - mean_eps: 0.100 - lives: 2.028
#
# Interval 283 (2820000 steps performed)
# 10000/10000 [==============================] - 101s 10ms/step - reward: 0.0217
# 13 episodes - episode_reward: 16.769 [9.000, 30.000] - loss: 0.008 - mae: 0.243 - mean_q: 0.294 - mean_eps: 0.100 - lives: 1.994
#
# Interval 284 (2830000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0205
# 15 episodes - episode_reward: 13.133 [6.000, 23.000] - loss: 0.008 - mae: 0.242 - mean_q: 0.293 - mean_eps: 0.100 - lives: 1.932
#
# Interval 285 (2840000 steps performed)
# 10000/10000 [==============================] - 101s 10ms/step - reward: 0.0253
# 16 episodes - episode_reward: 15.375 [8.000, 26.000] - loss: 0.008 - mae: 0.250 - mean_q: 0.302 - mean_eps: 0.100 - lives: 1.912
#
# Interval 286 (2850000 steps performed)
# 10000/10000 [==============================] - 101s 10ms/step - reward: 0.0199
# 15 episodes - episode_reward: 13.933 [6.000, 24.000] - loss: 0.008 - mae: 0.247 - mean_q: 0.297 - mean_eps: 0.100 - lives: 2.154
#
# Interval 287 (2860000 steps performed)
# 10000/10000 [==============================] - 101s 10ms/step - reward: 0.0214
# 17 episodes - episode_reward: 13.176 [5.000, 23.000] - loss: 0.008 - mae: 0.244 - mean_q: 0.296 - mean_eps: 0.100 - lives: 1.956
#
# Interval 288 (2870000 steps performed)
# 10000/10000 [==============================] - 101s 10ms/step - reward: 0.0247
# 13 episodes - episode_reward: 18.462 [10.000, 30.000] - loss: 0.007 - mae: 0.255 - mean_q: 0.308 - mean_eps: 0.100 - lives: 2.161
#
# Interval 289 (2880000 steps performed)
# 10000/10000 [==============================] - 101s 10ms/step - reward: 0.0210
# 15 episodes - episode_reward: 13.800 [8.000, 23.000] - loss: 0.008 - mae: 0.253 - mean_q: 0.307 - mean_eps: 0.100 - lives: 1.953
#
# Interval 290 (2890000 steps performed)
# 10000/10000 [==============================] - 101s 10ms/step - reward: 0.0225
# 12 episodes - episode_reward: 18.333 [12.000, 32.000] - loss: 0.008 - mae: 0.261 - mean_q: 0.315 - mean_eps: 0.100 - lives: 1.918
#
# Interval 291 (2900000 steps performed)
# 10000/10000 [==============================] - 101s 10ms/step - reward: 0.0178
# 11 episodes - episode_reward: 16.636 [7.000, 27.000] - loss: 0.008 - mae: 0.266 - mean_q: 0.322 - mean_eps: 0.100 - lives: 1.719
#
# Interval 292 (2910000 steps performed)
# 10000/10000 [==============================] - 101s 10ms/step - reward: 0.0227
# 14 episodes - episode_reward: 16.500 [6.000, 30.000] - loss: 0.008 - mae: 0.255 - mean_q: 0.308 - mean_eps: 0.100 - lives: 2.059
#
# Interval 293 (2920000 steps performed)
# 10000/10000 [==============================] - 101s 10ms/step - reward: 0.0208
# 16 episodes - episode_reward: 13.125 [5.000, 21.000] - loss: 0.008 - mae: 0.260 - mean_q: 0.314 - mean_eps: 0.100 - lives: 2.009
#
# Interval 294 (2930000 steps performed)
# 10000/10000 [==============================] - 101s 10ms/step - reward: 0.0219
# 14 episodes - episode_reward: 15.071 [4.000, 27.000] - loss: 0.008 - mae: 0.256 - mean_q: 0.310 - mean_eps: 0.100 - lives: 2.099
#
# Interval 295 (2940000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0192
# 14 episodes - episode_reward: 14.071 [5.000, 24.000] - loss: 0.007 - mae: 0.243 - mean_q: 0.294 - mean_eps: 0.100 - lives: 2.045
#
# Interval 296 (2950000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0224
# 13 episodes - episode_reward: 16.077 [10.000, 23.000] - loss: 0.008 - mae: 0.234 - mean_q: 0.283 - mean_eps: 0.100 - lives: 2.035
#
# Interval 297 (2960000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0215
# 15 episodes - episode_reward: 15.200 [8.000, 25.000] - loss: 0.008 - mae: 0.234 - mean_q: 0.283 - mean_eps: 0.100 - lives: 2.002
#
# Interval 298 (2970000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0187
# 16 episodes - episode_reward: 12.000 [5.000, 22.000] - loss: 0.007 - mae: 0.224 - mean_q: 0.269 - mean_eps: 0.100 - lives: 1.983
#
# Interval 299 (2980000 steps performed)
# 10000/10000 [==============================] - 99s 10ms/step - reward: 0.0192
# 16 episodes - episode_reward: 11.812 [5.000, 19.000] - loss: 0.007 - mae: 0.227 - mean_q: 0.275 - mean_eps: 0.100 - lives: 2.039
#
# Interval 300 (2990000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: 0.0246
# done, took 27281.008 seconds

# %%
# use PyvirtualDisplay to create a “virtual display” that we will send our rendered frames to
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()

# %%
# wrap a Monitor around environment
env_monitor = wrap_env(env)

# %%
# Testing part to calculate the mean reward
weights_filename = BASE_FOLDER+'dqn1_{}_weights.h5f'.format(env_name)
dqn.load_weights(weights_filename)
dqn.test(env_monitor, nb_episodes=10, visualize=True)
show_video()
# Out:
# Testing for 10 episodes ...
# Episode 1: reward: 24.000, steps: 967
# Episode 2: reward: 12.000, steps: 386
# Episode 3: reward: 14.000, steps: 627
# Episode 4: reward: 13.000, steps: 536
# Episode 5: reward: 19.000, steps: 799
# Episode 6: reward: 10.000, steps: 351
# Episode 7: reward: 25.000, steps: 980
# Episode 8: reward: 17.000, steps: 593
# Episode 9: reward: 11.000, steps: 536
# Episode 10: reward: 14.000, steps: 575
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# 3) Justificación de los parámetros seleccionados y de los resultados obtenidos
